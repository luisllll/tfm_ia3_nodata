# %% [markdown]
# ## Import necessary libraries

# %%
import torch

# Verifica si CUDA (GPU) está disponible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %%
# Python libraries
import datetime as dt
import re
import pickle
from tqdm.notebook import tqdm
import os
import sys
import time
import logging
import random
from collections import defaultdict, Counter

# Data Science modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
plt.style.use('ggplot')


# Import nltk modules and download dataset
import nltk
from nltk.corpus import stopwords
from nltk.util import ngrams
from nltk.tokenize import word_tokenize, sent_tokenize

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

stop = set(stopwords.words('english'))

# Import Pytorch modules
import torch
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import (DataLoader, RandomSampler, SequentialSampler, TensorDataset)
from torch.autograd import Variable
from torch.optim import Adam, AdamW
# Out:
# C:\Users\luisl\AppData\Local\Temp\ipykernel_11104\269888456.py:15: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\luisl\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\luisl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\luisl\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Set logger
logger = logging.getLogger('mylogger')
logger.setLevel(logging.INFO)

timestamp = time.strftime("%Y.%m.%d_%H.%M.%S", time.localtime())
formatter = logging.Formatter('[%(asctime)s][%(levelname)s] ## %(message)s')

fh = logging.FileHandler('log_model.txt')
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)
logger.addHandler(fh)

ch = logging.StreamHandler()
ch.setLevel(logging.INFO)
ch.setFormatter(formatter)
logger.addHandler(ch)

# %%
# Set Random Seed
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)
rand_seed = 42

# %%
# Set Seaborn Style
sns.set(style='white', context='notebook', palette='deep')

# %% [markdown]
# ## Load and process input data

# %% [markdown]
# Check the texts which is filtered by keyword as well

# %%
import pickle
import os

# Rutas de los archivos
ruta_original = 'C:/Users/Luis/Desktop/personal/tfm_ia3_nodata/data/preprocessed/'
ruta_nueva = 'C:/Users/luisl/OneDrive/Escritorio/TFM_IA3/tfm_ia3_nodata/data/preprocessed/'
archivos = ['text_no_split.pickle', 'text_keyword.pickle']

# Intentar cargar los archivos
text_no_split = None
text_keyword = None

for archivo in archivos:
    try:
        # Intenta abrir el archivo en la ruta original
        with open(os.path.join(ruta_original, archivo), 'rb') as file:
            if archivo == 'text_no_split.pickle':
                text_no_split = pickle.load(file)
            elif archivo == 'text_keyword.pickle':
                text_keyword = pickle.load(file)
        print(f"Archivo {archivo} encontrado en la ruta original.")
    except FileNotFoundError:
        try:
            # Si no se encuentra en la ruta original, intenta en la nueva
            with open(os.path.join(ruta_nueva, archivo), 'rb') as file:
                if archivo == 'text_no_split.pickle':
                    text_no_split = pickle.load(file)
                elif archivo == 'text_keyword.pickle':
                    text_keyword = pickle.load(file)
            print(f"Archivo {archivo} encontrado en la nueva ruta.")
        except FileNotFoundError:
            print(f"Archivo {archivo} no encontrado en ninguna de las rutas.")

# Usar las variables text_no_split y text_keyword según sea necesario.
# Out:
# Archivo text_no_split.pickle encontrado en la nueva ruta.
# Archivo text_keyword.pickle encontrado en la nueva ruta.

# %%
# Check the number of records per document type
def plot_num_rec_word(df):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(17,5))
    sns.countplot(x='type', data=df, ax=ax1)
    ax1.set_title('The number of records (original)', fontsize=16)
    ax1.tick_params('x', labelrotation=10)
    sns.barplot(data=df, x='type', y='word_count', ax=ax2)
    ax2.set_title('The number of words (original)', fontsize=16)
    ax2.tick_params('x', labelrotation=10)

# All texts
plot_num_rec_word(text_no_split)
text_no_split.head()
# Out:
#         type       date           title         speaker  word_count  decision  \
# 0  statement 1994-02-04  FOMC Statement  Alan Greenspan          99         1
# 1  statement 1994-03-22  FOMC Statement  Alan Greenspan          40         1
# 2  statement 1994-04-18  FOMC Statement  Alan Greenspan          37         1
# 3  statement 1994-05-17  FOMC Statement  Alan Greenspan          57         1
# 4  statement 1994-08-16  FOMC Statement  Alan Greenspan          51         1
#
#    rate next_meeting next_decision  next_rate  \
# 0  3.25   1994-02-28             0       3.25
# 1  3.50   1994-04-18             1       3.75
# 2  3.75   1994-05-17             1       4.25
# 3  4.25   1994-07-06             0       4.25
# 4  4.75   1994-09-27             0       4.75
#
#                                                 text
# 0  Chairman Alan Greenspan announced today that t...
# 1  Chairman Alan Greenspan announced today that t...
# 2  Chairman Alan Greenspan announced today that t...
# 3  In taking the discount action, the Board appro...
# 4  In taking the discount rate action, the Board ...

# %%
# Filtered by keywords
plot_num_rec_word(text_keyword)
text_keyword.head()
# Out:
#         type       date           title         speaker  word_count  decision  \
# 0  statement 1994-05-17  FOMC Statement  Alan Greenspan          38         1
# 1  statement 1994-11-15  FOMC Statement  Alan Greenspan          27         1
# 2  statement 1996-01-31  FOMC Statement  Alan Greenspan         403        -1
# 3  statement 1997-03-25  FOMC Statement  Alan Greenspan         432         1
# 4  statement 1998-09-29  FOMC Statement  Alan Greenspan         400        -1
#
#    rate next_meeting next_decision  next_rate  \
# 0  4.25   1994-07-06             0       4.25
# 1  5.50   1994-12-20             0       5.50
# 2  5.25   1996-03-26             0       5.25
# 3  5.50   1997-05-20             0       5.50
# 4  5.25   1998-10-15            -1       5.00
#
#                                                 text
# 0  The Board approved an increase in the discount...
# 1  In a related move, the Federal Open Market Com...
# 2  For immediate releaseThe Federal Reserve today...
# 3  For immediate release\tThe Federal Open Market...
# 4  For immediate releaseThe Federal Open Market C...

# %%
# # Drop meeting script data
# text_no_split = text_no_split.loc[text_no_split['type'] != 'meeting_script']
# text_split_200 = text_split_200.loc[text_split_200['type'] != 'meeting_script']
# text_keyword = text_keyword.loc[text_keyword['type'] != 'meeting_script']

# %% [markdown]
# ### Select text dataframe
# Here, use all the texts but keywords filtere one would give better performance - to be checked.

# %%
def combine_meeting_script(df):
    new_df = df.loc[df['type'] != 'meeting_script']
    print(new_df.shape)
    meeting_script_df = df.loc[df['type'] == 'meeting_script'].reset_index(drop=True)
    data_list = []
    for i, row in tqdm(meeting_script_df.iterrows(), total=meeting_script_df.shape[0]):
        if i == 0:
            prev_row = row
            continue
        if prev_row['date'].strftime('%Y-%m-%d') == row['date'].strftime('%Y-%m-%d'):
            prev_row['text'] = prev_row['text'] + row['text']
        else:
            prev_row['speaker'] = ""
            prev_row['word_count'] = len(re.findall(r'\b([a-zA-Z]+n\'t|[a-zA-Z]+\'s|[a-zA-Z]+)\b', prev_row['text']))
            data_list.append(list(prev_row))
            prev_row = row

    prev_row['speaker'] = ""
    prev_row['word_count'] = len(re.findall(r'\b([a-zA-Z]+n\'t|[a-zA-Z]+\'s|[a-zA-Z]+)\b', prev_row['text']))
    data_list.append(list(prev_row))
    new_meeting_script_df = pd.DataFrame(data_list, columns=df.columns)
    new_df = pd.concat([new_df, new_meeting_script_df], axis=0)
    print(new_df.shape)
    return new_df

train_df = combine_meeting_script(text_no_split)
plot_num_rec_word(train_df)
train_df.head()
# Out:
# (4339, 11)
#   0%|          | 0/9852 [00:00<?, ?it/s]
# (4597, 11)
#         type       date           title         speaker  word_count  decision  \
# 0  statement 1994-02-04  FOMC Statement  Alan Greenspan          99         1
# 1  statement 1994-03-22  FOMC Statement  Alan Greenspan          40         1
# 2  statement 1994-04-18  FOMC Statement  Alan Greenspan          37         1
# 3  statement 1994-05-17  FOMC Statement  Alan Greenspan          57         1
# 4  statement 1994-08-16  FOMC Statement  Alan Greenspan          51         1
#
#    rate next_meeting next_decision  next_rate  \
# 0  3.25   1994-02-28             0       3.25
# 1  3.50   1994-04-18             1       3.75
# 2  3.75   1994-05-17             1       4.25
# 3  4.25   1994-07-06             0       4.25
# 4  4.75   1994-09-27             0       4.75
#
#                                                 text
# 0  Chairman Alan Greenspan announced today that t...
# 1  Chairman Alan Greenspan announced today that t...
# 2  Chairman Alan Greenspan announced today that t...
# 3  In taking the discount action, the Board appro...
# 4  In taking the discount rate action, the Board ...

# %%
train_df.head()
# Out:
#         type       date           title         speaker  word_count  decision  \
# 0  statement 1994-02-04  FOMC Statement  Alan Greenspan          99         1
# 1  statement 1994-03-22  FOMC Statement  Alan Greenspan          40         1
# 2  statement 1994-04-18  FOMC Statement  Alan Greenspan          37         1
# 3  statement 1994-05-17  FOMC Statement  Alan Greenspan          57         1
# 4  statement 1994-08-16  FOMC Statement  Alan Greenspan          51         1
#
#    rate next_meeting next_decision  next_rate  \
# 0  3.25   1994-02-28             0       3.25
# 1  3.50   1994-04-18             1       3.75
# 2  3.75   1994-05-17             1       4.25
# 3  4.25   1994-07-06             0       4.25
# 4  4.75   1994-09-27             0       4.75
#
#                                                 text
# 0  Chairman Alan Greenspan announced today that t...
# 1  Chairman Alan Greenspan announced today that t...
# 2  Chairman Alan Greenspan announced today that t...
# 3  In taking the discount action, the Board appro...
# 4  In taking the discount rate action, the Board ...

# %%
# Calcular el número total de filas en el DataFrame
num_total_filas = train_df.shape[0]

print("Número total de filas en el DataFrame:", num_total_filas)
# Out:
# Número total de filas en el DataFrame: 4597

# %%
# Supongamos que tienes un DataFrame llamado df y una variable específica llamada 'variable_especifica'
variable_especifica = 'next_decision'

# Contar el número de filas con valores NaN en la variable especificada
num_filas_nan = train_df[variable_especifica].isnull().sum()

print("Número de filas con NaN en la variable '{}': {}".format(variable_especifica, num_filas_nan))
# Out:
# Número de filas con NaN en la variable 'next_decision': 31

# %%
# Filtrar el DataFrame para seleccionar solo las filas con valores NaN en la variable especificada
filas_nan = train_df[train_df[variable_especifica].isnull()]

# Obtener los valores de la columna "date" correspondientes a las filas con valores NaN
fechas_nan = filas_nan['date']

print("Valores de 'date' correspondientes a filas con NaN en la variable '{}':".format(variable_especifica))
print(fechas_nan)
# Out:
# Valores de 'date' correspondientes a filas con NaN en la variable 'next_decision':
# 201    2023-12-13
# 2151   2023-12-13
# 2152   2023-12-13
# 2153   2023-12-13
# 2154   2023-12-13
# 2155   2023-12-13
# 2156   2023-12-13
# 2157   2023-12-13
# 2158   2023-12-13
# 2159   2023-12-13
# 2160   2023-12-13
# 2161   2023-12-13
# 2162   2023-12-13
# 2163   2023-12-13
# 2164   2023-12-13
# 2165   2023-12-13
# 2166   2023-12-13
# 2167   2023-12-13
# 2168   2023-12-13
# 2169   2023-12-13
# 2170   2023-12-13
# 2171   2023-12-13
# 2172   2023-12-13
# 2173   2023-12-13
# 2174   2023-12-13
# 2175   2023-12-13
# 2176   2023-12-13
# 2177   2023-12-13
# 2178   2023-12-13
# 2179   2023-12-13
# 2180   2023-12-13
# Name: date, dtype: datetime64[ns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
train_df['next_decision'] = train_df['next_decision'].fillna('Missing')
# Crear el gráfico de conteo
plt.figure(figsize=(10, 6))
sns.countplot(data=train_df, x='next_decision')

# Añadir etiquetas y título
plt.xlabel('Next Decision')
plt.ylabel('Count')
plt.title('Distribucion de decisiones')

# Mostrar el gráfico
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para mayor claridad
plt.tight_layout()  # Ajustar el diseño para evitar solapamientos
plt.show()

# %%
# Check balance of Rate Decision
train_df['next_decision'] = train_df['next_decision'].fillna('Missing')
g = sns.FacetGrid(train_df, col='type', height=6, aspect=0.5)
g.map(sns.countplot, 'next_decision')
plt.show()
# Out:
# c:\Users\luisl\anaconda3\envs\tfm_modelado\lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Check distribution
def plot_distribution(df, kde):
    fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(15,10))
    doc_type = 'statement'
    sns.distplot(df.loc[df['type'] == doc_type]['word_count'], bins=20, ax=ax1, kde=kde, color='r')
    ax1.set_title(doc_type)
    doc_type = 'minutes'
    sns.distplot(df.loc[df['type'] == doc_type]['word_count'], bins=20, ax=ax2, kde=kde, color='y')
    ax2.set_title(doc_type)
    doc_type = 'presconf_script'
    sns.distplot(df.loc[df['type'] == doc_type]['word_count'], bins=20, ax=ax3, kde=kde, color='g')
    ax3.set_title(doc_type)
    doc_type = 'meeting_script'
    sns.distplot(df.loc[df['type'] == doc_type]['word_count'], bins=20, ax=ax4, kde=kde, color='b')
    ax4.set_title(doc_type)
    doc_type = 'speech'
    sns.distplot(df.loc[df['type'] == doc_type]['word_count'], bins=20, ax=ax5, kde=kde, color='purple')
    ax5.set_title(doc_type)
    doc_type = 'testimony'
    sns.distplot(df.loc[df['type'] == doc_type]['word_count'], bins=20, ax=ax6, kde=kde, color='orange')
    ax6.set_title(doc_type)

    fig.tight_layout(pad=1.0)
    plt.show()

plot_distribution(train_df, False)
train_df.tail()
# Out:
# C:\Users\luisl\AppData\Local\Temp\ipykernel_11104\4191536359.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df['type'] == doc_type]['word_count'], bins=20, ax=ax1, kde=kde, color='r')
# C:\Users\luisl\AppData\Local\Temp\ipykernel_11104\4191536359.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df['type'] == doc_type]['word_count'], bins=20, ax=ax2, kde=kde, color='y')
# C:\Users\luisl\AppData\Local\Temp\ipykernel_11104\4191536359.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df['type'] == doc_type]['word_count'], bins=20, ax=ax3, kde=kde, color='g')
# C:\Users\luisl\AppData\Local\Temp\ipykernel_11104\4191536359.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df['type'] == doc_type]['word_count'], bins=20, ax=ax4, kde=kde, color='b')
# C:\Users\luisl\AppData\Local\Temp\ipykernel_11104\4191536359.py:17: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df['type'] == doc_type]['word_count'], bins=20, ax=ax5, kde=kde, color='purple')
# C:\Users\luisl\AppData\Local\Temp\ipykernel_11104\4191536359.py:20: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df['type'] == doc_type]['word_count'], bins=20, ax=ax6, kde=kde, color='orange')
#                type       date                    title speaker  word_count  \
# 253  meeting_script 2014-04-30  FOMC Meeting Transcript               78299
# 254  meeting_script 2014-06-18  FOMC Meeting Transcript               87191
# 255  meeting_script 2014-07-30  FOMC Meeting Transcript               89115
# 256  meeting_script 2014-09-17  FOMC Meeting Transcript               61267
# 257  meeting_script 2014-10-29  FOMC Meeting Transcript               72330
#
#      decision  rate next_meeting next_decision  next_rate  \
# 253         0   0.0   2014-06-18             0        0.0
# 254         0   0.0   2014-07-30             0        0.0
# 255         0   0.0   2014-09-17             0        0.0
# 256         0   0.0   2014-10-29             1        0.0
# 257         1   0.0   2014-12-17             0        0.0
#
#                                                   text
# 253  Good morning, everybody. Unfortunately, this i...
# 254  I'd like to begin by welcoming three people to...
# 255  Good morning, everybody. I would like to begin...
# 256  Good morning, everybody.Our first two items th...
# 257  I'd like to call this meeting to order. Before...

# %% [markdown]
# ## Load a trained model

# %%
train_sent_df = train_df[train_df['type'] != 'meeting_script']

# %%
train_sent_df.head()
# Out:
#         type       date           title         speaker  word_count  decision  \
# 0  statement 1994-02-04  FOMC Statement  Alan Greenspan          99         1
# 1  statement 1994-03-22  FOMC Statement  Alan Greenspan          40         1
# 2  statement 1994-04-18  FOMC Statement  Alan Greenspan          37         1
# 3  statement 1994-05-17  FOMC Statement  Alan Greenspan          57         1
# 4  statement 1994-08-16  FOMC Statement  Alan Greenspan          51         1
#
#    rate next_meeting next_decision  next_rate  \
# 0  3.25   1994-02-28             0       3.25
# 1  3.50   1994-04-18             1       3.75
# 2  3.75   1994-05-17             1       4.25
# 3  4.25   1994-07-06             0       4.25
# 4  4.75   1994-09-27             0       4.75
#
#                                                 text
# 0  Chairman Alan Greenspan announced today that t...
# 1  Chairman Alan Greenspan announced today that t...
# 2  Chairman Alan Greenspan announced today that t...
# 3  In taking the discount action, the Board appro...
# 4  In taking the discount rate action, the Board ...

# %%
train_sent_df.shape
# Out:
# (4339, 11)

# %%
# Supongamos que quieres contar los NaN en la columna 'next_decision' de train_sent_df
nans_count = train_sent_df['next_decision'].isna().sum()

print(f"Número de valores NaN en la columna 'next_decision': {nans_count}")
# Out:
# Número de valores NaN en la columna 'next_decision': 0

# %%
train_sent_df = train_sent_df.dropna(subset=['next_decision'])
train_sent_df.shape
# Out:
# (4339, 11)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import scipy
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score
import torch
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification, BertTokenizer, BertForSequenceClassification
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Resumir los textos mediante modelado ##

# %%
from transformers import BartTokenizer, BartForConditionalGeneration, pipeline

# Assuming you have your train_sent_df DataFrame with a "text" column

# Load the BART model and tokenizer (correct tokenizer choice)
model_name = "facebook/bart-large-cnn"
tokenizer = BartTokenizer.from_pretrained(model_name)  # Use BartTokenizer
summarizer = pipeline("summarization", model=model_name)  # This might use BART tokenizer internally

# %%
# Function to handle potential errors during summarization
def summarize_text(text_to_summarize):
  try:
    # Tokenize the text (using BART tokenizer with truncation)
    input_ids = tokenizer(text_to_summarize, return_tensors="pt", truncation=True).input_ids.to(device)

    # Generate summary using pipeline (easier for smaller tasks)
    summary = summarizer(text_to_summarize, truncation=True, max_length=400, num_beams=5, early_stopping=True)[0]["summary_text"]

    return summary

  except RuntimeError as e:
    print(f"Error during processing text '{text_to_summarize}': {e}")
    return None  # Or a placeholder for failed summaries

# Slice DataFrame to last 1000 rows
train_sent_df_subset = train_sent_df.iloc[-500:]

# Loop through subset of DataFrame and summarize texts
for idx, row in tqdm(train_sent_df_subset.iterrows(), total=len(train_sent_df_subset)):
  text_to_summarize = row["text"]
  summary = summarize_text(text_to_summarize)

  if summary:  # Update DataFrame only if summarization succeeded
    train_sent_df_subset.loc[idx, 'summary'] = summary

# Update progress bar after loop (optional)
print("Summarization completed! Summaries added to 'summary' column.")
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
train_sent_df.head()
# Out:
#         type       date           title         speaker  word_count  decision  \
# 0  statement 1994-02-04  FOMC Statement  Alan Greenspan          99         1
# 1  statement 1994-03-22  FOMC Statement  Alan Greenspan          40         1
# 2  statement 1994-04-18  FOMC Statement  Alan Greenspan          37         1
# 3  statement 1994-05-17  FOMC Statement  Alan Greenspan          57         1
# 4  statement 1994-08-16  FOMC Statement  Alan Greenspan          51         1
#
#    rate next_meeting next_decision  next_rate  \
# 0  3.25   1994-02-28             0       3.25
# 1  3.50   1994-04-18             1       3.75
# 2  3.75   1994-05-17             1       4.25
# 3  4.25   1994-07-06             0       4.25
# 4  4.75   1994-09-27             0       4.75
#
#                                                 text
# 0  Chairman Alan Greenspan announced today that t...
# 1  Chairman Alan Greenspan announced today that t...
# 2  Chairman Alan Greenspan announced today that t...
# 3  In taking the discount action, the Board appro...
# 4  In taking the discount rate action, the Board ...

# %% [markdown]
# guardar texto resumido como pickle

# %%
import pandas as pd
import pickle

# Assuming your DataFrame is loaded and assigned to a variable named 'df'

# Define the path and filename for the pickle file
ruta_pickle = 'C:/Users/luisl/OneDrive/Escritorio/TFM_IA3/tfm_ia3_nodata/data/preprocessed/text_resumido_v2.pkl'

# Open the file in binary write mode
with open(ruta_pickle, 'wb') as pickle_file:
  # Use pickle.dump to serialize the DataFrame and write it to the file
  pickle.dump(train_sent_df, pickle_file)

print("¡DataFrame guardado como archivo pickle exitosamente!")
# Out:
# ¡DataFrame guardado como archivo pickle exitosamente!

# %% [markdown]
# cargar texto resumido

# %%
import pickle

# Define the path to the pickle file (same as before)
ruta_pickle = 'C:/Users/luisl/OneDrive/Escritorio/TFM_IA3/tfm_ia3_nodata/data/preprocessed/text_resumido_v2.pkl'

# Open the file in binary read mode
with open(ruta_pickle, 'rb') as pickle_file:
  # Use pickle.load to deserialize the data and create a new DataFrame
  loaded_df = pickle.load(pickle_file)

print("¡DataFrame cargado del archivo pickle exitosamente!")
# Out:
# ¡DataFrame cargado del archivo pickle exitosamente!

# %%
loaded_df.head()
# Out:
#         type       date           title         speaker  word_count  decision  \
# 0  statement 1994-02-04  FOMC Statement  Alan Greenspan          99         1
# 1  statement 1994-03-22  FOMC Statement  Alan Greenspan          40         1
# 2  statement 1994-04-18  FOMC Statement  Alan Greenspan          37         1
# 3  statement 1994-05-17  FOMC Statement  Alan Greenspan          57         1
# 4  statement 1994-08-16  FOMC Statement  Alan Greenspan          51         1
#
#    rate next_meeting next_decision  next_rate  \
# 0  3.25   1994-02-28             0       3.25
# 1  3.50   1994-04-18             1       3.75
# 2  3.75   1994-05-17             1       4.25
# 3  4.25   1994-07-06             0       4.25
# 4  4.75   1994-09-27             0       4.75
#
#                                                 text  \
# 0  Chairman Alan Greenspan announced today that t...
# 1  Chairman Alan Greenspan announced today that t...
# 2  Chairman Alan Greenspan announced today that t...
# 3  In taking the discount action, the Board appro...
# 4  In taking the discount rate action, the Board ...
#
#                                              summary
# 0  Decision to increase slightly the degree of pr...
# 1  The committee decided to increase slightly the...
# 2  The Federal Reserve will increase slightly the...
# 3  The Board of Directors of the Federal Reserve ...
# 4  The Board of Directors of the Federal Reserve ...

# %%
def equilibrar_columna_ignorando_missing(df, columna, valor_missing='Missing'):
    """
    Equilibra los valores en una columna específica de un DataFrame de pandas,
    ignorando los valores faltantes.
    
    Parámetros:
    - df: DataFrame de pandas.
    - columna: Nombre de la columna a equilibrar.
    - valor_missing: Valor que representa los datos faltantes en la columna.
    
    Retorna:
    - DataFrame equilibrado donde cada valor único en la columna especificada
      (excepto el valor_missing) tiene el mismo número de filas.
    """
    # Filtra los valores faltantes
    df_filtrado = df[df[columna] != valor_missing]
    
    # Calcula el número de filas para cada valor único en la columna filtrada
    counts = df_filtrado[columna].value_counts()
    
    # Encuentra el valor mínimo de filas entre los grupos
    min_count = counts.min()
    
    # Reduce cada grupo a este número mínimo de filas
    balanced_df = df_filtrado.groupby(columna).head(min_count).reset_index(drop=True)
    
    return balanced_df

# %%
# Uso de la función
# Suponiendo que train_sent_df es tu DataFrame, 'next_decision' es la columna a equilibrar,
# y 'Missing' representa los valores faltantes en esa columna
train_sent_df = equilibrar_columna_ignorando_missing(loaded_df, 'next_decision', 'Missing')

# Verificación del nuevo balance de clases (sin contar los missing)

# %%
print(train_sent_df['next_decision'].value_counts())
# Out:
# next_decision
# 0     453
# 1     453
# -1    453
# Name: count, dtype: int64

# %%
X = train_sent_df['summary'].to_list()

# %%
train_sent_df.head()
# Out:
#         type       date           title         speaker  word_count  decision  \
# 0  statement 1994-02-04  FOMC Statement  Alan Greenspan          99         1
# 1  statement 1994-03-22  FOMC Statement  Alan Greenspan          40         1
# 2  statement 1994-04-18  FOMC Statement  Alan Greenspan          37         1
# 3  statement 1994-05-17  FOMC Statement  Alan Greenspan          57         1
# 4  statement 1994-08-16  FOMC Statement  Alan Greenspan          51         1
#
#    rate next_meeting next_decision  next_rate  \
# 0  3.25   1994-02-28             0       3.25
# 1  3.50   1994-04-18             1       3.75
# 2  3.75   1994-05-17             1       4.25
# 3  4.25   1994-07-06             0       4.25
# 4  4.75   1994-09-27             0       4.75
#
#                                                 text  \
# 0  Chairman Alan Greenspan announced today that t...
# 1  Chairman Alan Greenspan announced today that t...
# 2  Chairman Alan Greenspan announced today that t...
# 3  In taking the discount action, the Board appro...
# 4  In taking the discount rate action, the Board ...
#
#                                              summary
# 0  Decision to increase slightly the degree of pr...
# 1  The committee decided to increase slightly the...
# 2  The Federal Reserve will increase slightly the...
# 3  The Board of Directors of the Federal Reserve ...
# 4  The Board of Directors of the Federal Reserve ...

# %%
import pandas as pd

# Porcentaje deseado de las filas (e.g., 10%)
porcentaje = 100

# Calcula el número de filas a seleccionar basado en el porcentaje
num_filas = int(len(train_sent_df) * (porcentaje / 100))

# Selecciona aleatoriamente el porcentaje deseado de filas del DataFrame
submuestra_df = train_sent_df.sample(n=num_filas)

submuestra_df = submuestra_df.dropna(subset=['next_decision'])

# Convierte la columna deseada a una lista
X_submuestra = submuestra_df['summary'].to_list()

# %%
nan_count = submuestra_df['next_decision'].isnull().sum()
nan_count
# Out:
# 0

# %%
data = train_sent_df[['summary', 'next_decision']]
# Reemplazar los valores en la columna específica
data['next_decision'] = data['next_decision'].replace({1: 2, 0: 1, -1: 0})
# Out:
# C:\Users\luisl\AppData\Local\Temp\ipykernel_10744\1924414100.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['next_decision'] = data['next_decision'].replace({1: 2, 0: 1, -1: 0})
# C:\Users\luisl\AppData\Local\Temp\ipykernel_10744\1924414100.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['next_decision'] = data['next_decision'].replace({1: 2, 0: 1, -1: 0})

# %%
data = data.rename(columns={'summary': 'text', 'next_decision': 'label'})

# %%
from sklearn.model_selection import train_test_split

# Dividir el DataFrame en conjuntos de entrenamiento y prueba (80% train, 20% test)
train_df, test_df = train_test_split(data, test_size=0.2, random_state=42)

# Mostrar los tamaños de los conjuntos de train y test
print("Tamaño del conjunto de entrenamiento:", len(train_df))
print("Tamaño del conjunto de prueba:", len(test_df))
# Out:
# Tamaño del conjunto de entrenamiento: 1087
# Tamaño del conjunto de prueba: 272

# %%
train_data = train_df.to_dict(orient='records')
val_data = test_df.to_dict(orient='records')
data = data.to_dict(orient='records')

# %%
train_data
# Out:
# [{'text': 'Chairman Powell answers questions from reporters.', 'label': 2},
#  {'text': 'Here is the full text of the remarks by Boston Fed chair Evans:',
#   'label': 0},
#  {'text': 'Staff presented two illustrative scenarios for long-run target portfolio composition.',
#   'label': 1},
#  {'text': 'Chair Powell: Trade policy uncertainty is one of them.',
#   'label': 0},
#  {'text': 'The Federal Open Market Committee decided to keep its target for the federal funds rate at 1 percent.',
#   'label': 1},
#  {'text': "Powell: China reopening is a risky situation, but it doesn't seem likely to have material effect",
#   'label': 2},
#  {'text': 'T-bill purchases and repo operations have been described as liquidity.',
#   'label': 0},
#  {'text': 'Information received since the Federal Open Market Committee met in January suggests that economic activity has continued to strengthen.',
#   'label': 1},
#  {'text': "Chairman: I don't accept premise that Fed has been passive.",
#   'label': 1},
#  {'text': 'I am pleased to be addressing the new American Bankers Association.',
#   'label': 0},
#  {'text': "Here is the full text of Chairman Powell's remarks at a news conference.",
#   'label': 2},
#  {'text': 'Is lower rates going to solve the capital cost problem?',
#   'label': 0},
#  {'text': 'Here is the text of my remarks at the annual NABE meeting.',
#   'label': 0},
#  {'text': 'Here is the full text of the testimony:', 'label': 0},
#  {'text': 'Final budget projections show further upward revisions to on-budget surpluses.',
#   'label': 0},
#  {'text': 'Critics say Fed should have acted sooner to contain stock-market bubbles.',
#   'label': 0},
#  {'text': "Here is the full text of Fed chair's remarks at press conference.",
#   'label': 2},
#  {'text': "S&P move didn't really tell us anything: Yellen", 'label': 1},
#  {'text': 'The facility will allow FIMA account holders to enter into repurchase agreements.',
#   'label': 1},
#  {'text': 'Here is the full transcript of the press conference:', 'label': 2},
#  {'text': 'What are your discussions with central banks on an ongoing basis?',
#   'label': 0},
#  {'text': 'New titles for managers of System Open Market Account, Foreign Operations.',
#   'label': 1},
#  {'text': "Here are some highlights from Chairman Bernanke's press conference.",
#   'label': 1},
#  {'text': 'Pace of asset purchases to be reduced to $35 billion per month.',
#   'label': 1},
#  {'text': 'Realism in the Financial Sector, individual decisions, and the international sphere.',
#   'label': 2},
#  {'text': 'Chair Powell: We do understand what risks banks are running.',
#   'label': 0},
#  {'text': 'The Committee decided to keep the target range for the federal funds rate at 5-1/4 to 5 percent.',
#   'label': 1},
#  {'text': 'Committee votes to extend reciprocal currency arrangements with the Bank of Canada and the Banco de Mexico.',
#   'label': 1},
#  {'text': 'Here is the full text of his press conference on 23 April.',
#   'label': 0},
#  {'text': 'Here is the full text of remarks by Fed chair Powell at press conference:',
#   'label': 2},
#  {'text': 'The Open Market Committee decided today to tighten market conditions slightly. No change was made to the Federal Reserve discount rate',
#   'label': 1},
#  {'text': 'The following statement is issued after the Federal Open Market Committee meeting.',
#   'label': 1},
#  {'text': 'Chairman: This is not a month-to-month proposition.', 'label': 1},
#  {'text': 'The Fed decided to keep the target range for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': 'At more than $500 billion, the deficits in trade and current account balances are quite large.',
#   'label': 2},
#  {'text': "Here is the full text of Powell's remarks:", 'label': 0},
#  {'text': 'The Federal Reserve releases the minutes of its September meeting.',
#   'label': 1},
#  {'text': 'Financial stability is a fundamental objective of central banks.',
#   'label': 0},
#  {'text': 'Here is the full text of the remarks by Federal Reserve chair Janet Yellen:',
#   'label': 0},
#  {'text': 'Board views special exception for ILCs in federal law.',
#   'label': 0},
#  {'text': 'Median expectations for the target federal funds rate moved up slightly.',
#   'label': 1},
#  {'text': 'Is the lack of clarity about what Congress is going to do negative for sentiment?',
#   'label': 1},
#  {'text': 'What do you make of foreign central banks buying U.S. Treasuries?',
#   'label': 1},
#  {'text': 'System Open Market Account manager first discussed developments in financial markets. Equity prices rose, with the S&P 500 index reaching a record high',
#   'label': 1},
#  {'text': 'Financial markets remained substantially tighter than at the start of the year.',
#   'label': 2},
#  {'text': 'Information received since the Federal Open Market Committee met in March suggests that economic activity has been expanding at a moderate pace.',
#   'label': 2},
#  {'text': 'Here is the full text of the testimony by Janet Yellen:',
#   'label': 0},
#  {'text': 'Manager also reports on System open market operations in Treasury securities, agency debt, and MBS.',
#   'label': 1},
#  {'text': "Chair Powell: We don't see significant tightening of credit yet.",
#   'label': 2},
#  {'text': 'Is the federal funds rate too high?', 'label': 2},
#  {'text': "Here is the full text of the Fed's statement after its latest policy meeting.",
#   'label': 0},
#  {'text': 'Is there a point at which guidance is no longer tenable?',
#   'label': 0},
#  {'text': 'Pace of economic activity has slowed from solid rate in fourth quarter.',
#   'label': 1},
#  {'text': 'Sarbanes-Oxley and the role of internal auditors.', 'label': 0},
#  {'text': 'Reforms over the past century have served us well.', 'label': 0},
#  {'text': "Here is the text of Federal Reserve chair Janet Yellen's speech at the Olin School:",
#   'label': 0},
#  {'text': "Here is the full text of President Obama's statement:", 'label': 0},
#  {'text': 'Q&A with Fed chair: How much will lower rates affect demand?',
#   'label': 1},
#  {'text': 'Questions for the chair of the Federal Reserve.', 'label': 1},
#  {'text': 'Do you think a major mortgage settlement would do a lot to help?',
#   'label': 1},
#  {'text': 'Chairman Powell speaks at the Economic Club of America in Washington.',
#   'label': 2},
#  {'text': "Here is the full text of Chairman Powell's remarks at the press conference.",
#   'label': 2},
#  {'text': 'Agency debt and MBS lending approved by unanimous vote.',
#   'label': 1},
#  {'text': 'Economic growth has slowed recently, partly reflecting softening of household spending. Tight credit conditions, the ongoing housing contraction, and some slowing in export growth',
#   'label': 1},
#  {'text': 'Here is the full text of remarks by Fed chair Janet Yellen at press conference:',
#   'label': 2},
#  {'text': 'I would like to begin by noting that the Federal Reserve has been involved in a wide range of activities in recent months.',
#   'label': 0},
#  {'text': 'Wages are not the principal story of why prices are going up.',
#   'label': 2},
#  {'text': 'Is the leverage ratio acceptable?', 'label': 1},
#  {'text': 'Pace of increases in target range for funds rate to be consistent with sustained expansion of economic activity.',
#   'label': 1},
#  {'text': 'I have already addressed some of the basic considerations that confront the emergence and persistence of a single currency.',
#   'label': 0},
#  {'text': 'Q&A follows: Is it true that the Fed sets an inflation target of 2 percent?',
#   'label': 1},
#  {'text': "Chair Powell: Guidance is not binding, but it's the beginning of the story",
#   'label': 0},
#  {'text': 'Here is the full text of the remarks by Chair Powell.', 'label': 2},
#  {'text': 'Q&A on inflation: Is it time to put more weight on private data?',
#   'label': 2},
#  {'text': "Here is the full text of Ben Bernanke's press conference:",
#   'label': 1},
#  {'text': 'Q&A with Yellen on mortgage-backed securities purchases. Chairman, what is your appetite for a renewed push into large-scale MBS purchases?',
#   'label': 1},
#  {'text': 'What signal would you give if you made a big change in policy?',
#   'label': 1},
#  {'text': 'Report from the Open Market Desk at the Federal Reserve Bank of New York.',
#   'label': 1},
#  {'text': 'Several participants indicated willingness to explore changes to the Summary of Economic Projections.',
#   'label': 1},
#  {'text': 'The Committee noted that economic activity had been solid before the landfall of Hurricane Katrina.',
#   'label': 2},
#  {'text': 'Economist asks Yellen about nearterm growth and unemployment forecasts.',
#   'label': 2},
#  {'text': "Chairman: We're getting reactions and comments on the rule.",
#   'label': 1},
#  {'text': 'Here is the text of the statement issued by Fed chair:',
#   'label': 0},
#  {'text': 'Is a 14 point cut really going to address all of that?',
#   'label': 0},
#  {'text': 'Financial market disruptions can pose significant risks to the macroeconomy.',
#   'label': 0},
#  {'text': 'Chair Powell, what is your definition of a recession?', 'label': 2},
#  {'text': 'System Open Market Account opened by the Federal Reserve Bank of New York.',
#   'label': 1},
#  {'text': 'Information received since the Federal Open Market Committee met in November suggests that the economy has been expanding moderately.',
#   'label': 1},
#  {'text': 'The Committee decided to keep the target range for the federal funds rate at 0 to 1/4 percent.',
#   'label': 1},
#  {'text': 'Committee approved an amendment to paragraph 2 of the Authorization for Domestic Open Market Operations.',
#   'label': 1},
#  {'text': 'Joint proposal on real estate brokerage and management was published on January 3, 2001.',
#   'label': 0},
#  {'text': 'Interagency proposal to amend the U.S. regulatory capital framework was published in June 2012.',
#   'label': 0},
#  {'text': 'The Committee decided to keep the target for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': 'The supervisory response to change is incomplete, I think.',
#   'label': 2},
#  {'text': "Staff briefings on changes in banks' uses of reserves.",
#   'label': 2},
#  {'text': 'Committee decided to extend reciprocal currency arrangements with the Bank of Canada and the Banco de.',
#   'label': 2},
#  {'text': "Here is the text of Federal Reserve chair Janet Yellen's speech on Wednesday.",
#   'label': 0},
#  {'text': "Here is the full text of Fed Chair Yellen's remarks at press conference:",
#   'label': 2},
#  {'text': 'The Federal Open Market Committee voted unanimously to lower the target for the federal funds rate by 25 basis points to 4 percent.',
#   'label': 1},
#  {'text': 'Chair Powell on financial stability: leverage at comfortable level',
#   'label': 0},
#  {'text': 'Many participants expect rates to return to what they think are normal longer-run levels.',
#   'label': 2},
#  {'text': 'Q&A with Fed chairman Hilsenrath: Is there a risk disinflationary forces will not be as strong?',
#   'label': 0},
#  {'text': 'Is there a role for monetary policy in an outbreak?', 'label': 0},
#  {'text': "Chairman: We don't know yet, we don't know", 'label': 0},
#  {'text': "Chair Powell: We won't hesitate to change stance of monetary policy",
#   'label': 0},
#  {'text': 'I will discuss the role of central bank communication in promoting this commitment.',
#   'label': 0},
#  {'text': 'The Committee decided to keep the target for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': 'Pace of economic growth has slowed from moderate pace of third quarter.',
#   'label': 1},
#  {'text': 'Chair Powell talks about the importance of getting inflation under control.',
#   'label': 2},
#  {'text': 'Below is the full text of the speech by Fed chair Janet Yellen:',
#   'label': 0},
#  {'text': 'I believe the United States is not at the brink of significant and sustained deflation.',
#   'label': 0},
#  {'text': 'Credit crunch poses meaningful downside risks to real economy.',
#   'label': 0},
#  {'text': 'Signs of decelerating economic activity have emerged.', 'label': 0},
#  {'text': 'Economic activity expanded at a solid pace in third quarter. Consumer spending rose more strongly after a tepid increase in the second quarter',
#   'label': 1},
#  {'text': 'Manager of the System Open Market Account reports on developments in domestic and foreign markets.',
#   'label': 1},
#  {'text': 'Financial conditions eased, inflation expectations little changed. Balance sheet runoff was proceeding smoothly',
#   'label': 2},
#  {'text': 'Committee sees upside risks to price stability for next few quarters.',
#   'label': 2},
#  {'text': 'Q&A with Fed chair: What is your best guess on when to start to withdraw stimulus?',
#   'label': 1},
#  {'text': 'Here is the text of remarks by Federal Reserve chair Janet Yellen.',
#   'label': 0},
#  {'text': "Below is the full text of Fed chair Janet Yellen's speech at the Fed conference:",
#   'label': 1},
#  {'text': "Q&A follows: Did you say it's likely that the U.S. is in a recession?",
#   'label': 2},
#  {'text': 'I would like to thank you for hosting this meeting.', 'label': 0},
#  {'text': 'BBC economics correspondent Michelle Fleury asks about the outlook for jobs.',
#   'label': 1},
#  {'text': 'Chair Powell: There are too many areas of the economy that are performing, too well.',
#   'label': 2},
#  {'text': 'Chair Powell: Disinflationary process has started in goods prices.',
#   'label': 2},
#  {'text': 'The Committee decided to expand existing swap arrangements and to enter into new arrangements with foreign central banks.',
#   'label': 1},
#  {'text': "Black workers' unemployment rebounded in May. Chair Powell: All unemployment, including Black unemployment, has been bouncing around",
#   'label': 2},
#  {'text': 'Fed chair speaks at press conference in Washington.', 'label': 2},
#  {'text': 'SIFMA blames fiscal cliff, Europe for slow hiring.', 'label': 1},
#  {'text': "I think there's some confusion about how the Committee is responding.",
#   'label': 0},
#  {'text': "Chairman: I'm a little bit more sympathetic to central bankers.",
#   'label': 1},
#  {'text': 'Information technology has played a central role in the economy.',
#   'label': 2},
#  {'text': 'Questions for Fed chair in press conference.', 'label': 2},
#  {'text': 'Staff briefings focused on forward guidance, negative rates, and balance sheet policy tools.',
#   'label': 1},
#  {'text': 'Higher rates, slower growth, and a softening labor market are all painful.',
#   'label': 2},
#  {'text': 'Questions on capital requirements, real-time payment system',
#   'label': 0},
#  {'text': 'Chairman, Vice Chairman, and Alternate Members to speak.',
#   'label': 1},
#  {'text': 'Q&A with Yellen on inflation: What is the number-one thing for you?',
#   'label': 2},
#  {'text': 'The Committee noted that economic activity was increasing at a subdued rate.',
#   'label': 1},
#  {'text': 'I would suggest that recent market turbulence was a function of reassessing risk.',
#   'label': 0},
#  {'text': 'Economic growth is likely to continue at a moderate pace over coming quarters.',
#   'label': 1},
#  {'text': 'Information received suggests that economic activity decelerated somewhat over the first half of this year.',
#   'label': 0},
#  {'text': "Bank of England policymaker: No, we're focused on macroeconomic outcomes.",
#   'label': 2},
#  {'text': 'The Board of Governors of the Federal Reserve has decided to reduce the discount rate to 4 percent.',
#   'label': 0},
#  {'text': 'Payment systems in the United States have been for many years.',
#   'label': 2},
#  {'text': 'Pace of purchases of Treasuries, mortgage-backed securities to continue.',
#   'label': 1},
#  {'text': "Here is the full text of Powell's press conference:", 'label': 2},
#  {'text': 'I was a banker for more than 30 years before becoming a Board member.',
#   'label': 0},
#  {'text': 'The Committee decided to extend for one year the reciprocal currency swap arrangements with the Bank of Canada and the Bank of Mexico.',
#   'label': 1},
#  {'text': "Here is the full text of Chairman Powell's remarks at the press conference.",
#   'label': 2},
#  {'text': 'How would a rate cut affect your business?', 'label': 0},
#  {'text': 'I am happy to address this conference, now in its eighth year.',
#   'label': 2},
#  {'text': "Payments, a key part of the country's economic infrastructure, and Fed activities",
#   'label': 0},
#  {'text': "Here is the full text of Chairman Powell's remarks:", 'label': 0},
#  {'text': 'Information reviewed at the August meeting indicated that the economy expanded at a moderate pace in the second quarter.',
#   'label': 1},
#  {'text': 'Staff presentation on dynamic general equilibrium models.',
#   'label': 1},
#  {'text': 'Pace of asset purchases to be maintained at $40 billion per month.',
#   'label': 1},
#  {'text': 'Committee unanimously approves publication of summary statement of monetary policy normalization principles.',
#   'label': 2},
#  {'text': 'Policymakers decided to keep the target for the federal funds rate at zero to 0.25%.',
#   'label': 1},
#  {'text': "Social security is the federal government's largest and most popular program.",
#   'label': 2},
#  {'text': "U.S. bank regulator says he doesn't know what Europe is doing with its capital.",
#   'label': 1},
#  {'text': 'Pace of asset purchases to be reduced to $30 billion per month.',
#   'label': 1},
#  {'text': "I wouldn't want to put a number on what that might be.",
#   'label': 2},
#  {'text': 'Here is the text of the remarks by Federal Reserve chair Janet Yellen:',
#   'label': 0},
#  {'text': 'Chairman Bernanke: Too-big-to-fail was an important cause of crisis',
#   'label': 0},
#  {'text': 'Pace of asset purchases to be maintained at $40 billion per month.',
#   'label': 2},
#  {'text': 'I will discuss recent market developments and their economic implications.',
#   'label': 0},
#  {'text': "Here is the full text of Chair Powell's remarks.", 'label': 2},
#  {'text': "renewal of System's swap arrangements with foreign central banks.",
#   'label': 0},
#  {'text': 'Here is the full text of remarks by Fed chair Janet Yellen:',
#   'label': 2},
#  {'text': 'Economic activity exhibited little, if any, upward movement in midsummer',
#   'label': 1},
#  {'text': 'The Committee decided to keep the target range for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': 'I was wondering if you could explain what is persisting in terms of holding the recovery back.',
#   'label': 1},
#  {'text': 'Panel discussed financial market developments, Open Market Desk surveys, and economic outlook.',
#   'label': 1},
#  {'text': 'The Committee noted that economic activity advanced at a moderate rate early in the third quarter.',
#   'label': 0},
#  {'text': 'Chairman Borak: Regulators are in middle of rule-writing process.',
#   'label': 1},
#  {'text': 'Weekly take on events in the world economy and their fallout.',
#   'label': 2},
#  {'text': 'Chair Powell: Labor market is strong for some time', 'label': 2},
#  {'text': 'Fed’s Rogoff and Reinhart discuss the impact of monetary policy.',
#   'label': 1},
#  {'text': 'Chairman Powell on inflation, supply shocks: “We have now experienced an extraordinary series of shocks.”',
#   'label': 2},
#  {'text': 'I will review the evolution of U.S. monetary policy since late 2007.',
#   'label': 0},
#  {'text': "Here is the full text of Powell's remarks at the press conference:",
#   'label': 2},
#  {'text': 'Consumer and mortgage loans have not suffered the sharp run-up in delinquencies.',
#   'label': 0},
#  {'text': 'Chair Powell says review of supervision and regulation to be thorough and transparent.',
#   'label': 2},
#  {'text': "Here is a full transcript of Chairman Powell's press conference:",
#   'label': 0},
#  {'text': 'I would say that would be a successful outcome.', 'label': 2},
#  {'text': 'Here is the full text of remarks by Fed chair:', 'label': 2},
#  {'text': "Here is the full text of Fed chair Ben Bernanke's speech in Washington.",
#   'label': 0},
#  {'text': "CNNMoney's Scott Spoerry answers your questions on the economy.",
#   'label': 0},
#  {'text': 'Monetary policy played a modest but important role.', 'label': 0},
#  {'text': 'Pace of job gains remains solid, but inflation remains below 2 percent.',
#   'label': 0},
#  {'text': 'Chairman: We still have considerable scope to do more.',
#   'label': 1},
#  {'text': "Policy tilt has eased financial conditions, and that's helping economy.",
#   'label': 0},
#  {'text': "Here is the full text of Ben Bernanke's press conference.",
#   'label': 1},
#  {'text': "Here is the full text of Powell's remarks at the St. Louis Fed conference:",
#   'label': 0},
#  {'text': "The vote to renew the System's participation in the swap arrangements maturing in December was taken at this meeting.",
#   'label': 1},
#  {'text': 'You mentioned before the streak of bad luck that struck the economy.',
#   'label': 1},
#  {'text': 'Q&A with Chairman Powell on broad effort to normalize rates.',
#   'label': 2},
#  {'text': 'Is there any new guidance on leveraged lending?', 'label': 0},
#  {'text': "Here is the full text of Bank of England governor's remarks:",
#   'label': 2},
#  {'text': 'Here is the full text of the statement by Fed chair:', 'label': 2},
#  {'text': 'Committee sees more promising outlook for economic recovery.',
#   'label': 1},
#  {'text': 'The Board of Governors approved a 50 basis point reduction in the discount rate to 4 percent.',
#   'label': 1},
#  {'text': 'Authorization raised from $8 billion to $12 billion.', 'label': 1},
#  {'text': 'Chairman Powell answers question on framework review.', 'label': 0},
#  {'text': 'John Taylor, who has died, was an influential economist.',
#   'label': 0},
#  {'text': 'Pace of asset purchases to continue, $40 billion per month.',
#   'label': 1},
#  {'text': 'The Committee decided to keep the target for the federal funds rate at 0 to 0.25%.',
#   'label': 2},
#  {'text': 'I would like to take this opportunity to thank you for your work.',
#   'label': 0},
#  {'text': "Here is the full text of President Obama's statement after the Federal Reserve meeting:",
#   'label': 1},
#  {'text': 'Fed chair: Is the Fed part of the problem?', 'label': 1},
#  {'text': 'Federal Reserve chair remarks at Siena College.', 'label': 0},
#  {'text': 'Economic stability will need to be restored.', 'label': 0},
#  {'text': 'Here is the text of the testimony by Federal Reserve Bank of San Francisco chair:',
#   'label': 0},
#  {'text': 'Questions about strains in global financial markets were raised in the statement.',
#   'label': 0},
#  {'text': 'The Board of Directors of the Federal Reserve has decided to reduce the discount rate by 0.25%.',
#   'label': 1},
#  {'text': 'These facilities are designed to help improve liquidity conditions in U.S. dollar funding markets.',
#   'label': 1},
#  {'text': 'I am writing to provide an update on Federal Reserve actions to strengthen market infrastructure.',
#   'label': 0},
#  {'text': 'Jackie Joyner-Kersee has chosen to do much more for her hometown.',
#   'label': 0},
#  {'text': 'Core inflation is a better predictor of inflation going forward.',
#   'label': 2},
#  {'text': 'Yellen: Tight labor market driving inflation now.', 'label': 2},
#  {'text': "Chairman Powell: We don't directly affect the price of oil",
#   'label': 2},
#  {'text': 'Pace of increases no longer important, Powell says.', 'label': 2},
#  {'text': 'Agency securities to be bought and sold in open market under agreements.',
#   'label': 1},
#  {'text': 'Chairman Powell spoke at the Economic Club of America in Washington.',
#   'label': 2},
#  {'text': 'Chairman: We have used some different tools.', 'label': 1},
#  {'text': 'Bank of England governor comments on too-big-to-fail firms.',
#   'label': 0},
#  {'text': 'The Committee decided to release the minutes of its June meeting.',
#   'label': 1},
#  {'text': 'Here is the full text of the statement after the Federal Reserve meeting:',
#   'label': 1},
#  {'text': 'Press conference held after Fed decision to end bond-buying program.',
#   'label': 1},
#  {'text': "I will offer bridge from today's discussion of structural changes to the implications for monetary policy.",
#   'label': 2},
#  {'text': 'Authorization for domestic open market operations effective January 30, 2007.',
#   'label': 1},
#  {'text': "Here is the full text of Yellen's testimony to the Senate Banking Committee.",
#   'label': 2},
#  {'text': "Q&A with Fed chair: Is there a risk that some of those prices simply don't come down?",
#   'label': 2},
#  {'text': 'The Board of Directors of the Federal Reserve has decided to increase the discount rate by 0.25%.',
#   'label': 1},
#  {'text': 'Information received since the Committee met in December suggests that the economy has weakened further.',
#   'label': 1},
#  {'text': 'Committee decided to keep the target range for the federal funds rate at 1 to 2 percentage points.',
#   'label': 2},
#  {'text': 'Questions for Powell in response to Timiraos.', 'label': 2},
#  {'text': 'Inflation still expected to be elevated next year, but fed funds rate lower than now.',
#   'label': 2},
#  {'text': 'Here are remarks from Fed chair Janet Yellen on conditionality:',
#   'label': 1},
#  {'text': 'Here is the full text of the remarks by Fed chair Janet Yellen:',
#   'label': 2},
#  {'text': 'Questions about reinvestments, balance sheet shrink.', 'label': 2},
#  {'text': 'The surge in spending on high-tech equipment and software has been decisive.',
#   'label': 2},
#  {'text': 'Q&A with Yellen on oil prices, deflation and U.S. economy.',
#   'label': 2},
#  {'text': 'The Committee decided to keep the target for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': 'Here is the text of the remarks by Fed chair Janet Yellen:',
#   'label': 0},
#  {'text': "Here is the full text of Powell's remarks at the Press Conference.",
#   'label': 2},
#  {'text': "Here is the full text of Powell's press conference:", 'label': 2},
#  {'text': 'I would say that the overall picture is that inflation was becoming from very strong demand for goods',
#   'label': 2},
#  {'text': 'Pace of policy accommodation can be removed at a pace that is likely to be measured.',
#   'label': 2},
#  {'text': "Here is the full text of Powell's remarks.", 'label': 2},
#  {'text': 'Slowdown began late last year when manufacturers cut output sharply.',
#   'label': 0},
#  {'text': 'Committee adopted domestic policy directive.', 'label': 2},
#  {'text': 'Chairman Powell: Consumers in good shape financially, not seeing broad slowdown',
#   'label': 2},
#  {'text': "Here is the full text of Chairman Powell's remarks at a press conference:",
#   'label': 0},
#  {'text': 'Is it early to anticipate economic effects of the fiscal cliff?',
#   'label': 1},
#  {'text': 'Rationale for tightening is straightforward, flows from two assessments.',
#   'label': 2},
#  {'text': 'Chairman Powell talks about the state of the labor market in his press conference.',
#   'label': 2},
#  {'text': 'Changes in the business of banking have been significant over the past several decades.',
#   'label': 0},
#  {'text': "Here is the full text of Powell's remarks after the Fed meeting.",
#   'label': 2},
#  {'text': 'Your role in strengthening internal control and transparency is a major one.',
#   'label': 0},
#  {'text': 'Has the recent rise in gasoline prices created a bulge in headline inflation?',
#   'label': 0},
#  {'text': 'I am pleased to address the inaugural Community Reinvestment Fund Forum Series.',
#   'label': 0},
#  {'text': 'Bank supervision, transparency and accountability need to be priorities, says CFPB director.',
#   'label': 0},
#  {'text': 'Inflation has not moved to our goal on a sustained basis',
#   'label': 0},
#  {'text': 'I would like to offer a macroeconomic perspective on the evolving demand for skills.',
#   'label': 2},
#  {'text': 'Economic activity exhibited little, if any, upward movement in midsummer',
#   'label': 1},
#  {'text': 'Q&A with Powell on inflation, non-sorry economy', 'label': 2},
#  {'text': 'Committee members discussed the potential value and drawbacks of this type of exercise.',
#   'label': 0},
#  {'text': 'The Federal Reserve will increase slightly the degree of pressure on reserve positions.',
#   'label': 2},
#  {'text': 'The Board of Directors of the Federal Reserve Banks of Boston, New York, Richmond, Chicago, St. Louis, Kansas City and San Francisco.',
#   'label': 1},
#  {'text': 'Officers selected to serve until the selection of their successors.',
#   'label': 2},
#  {'text': 'What are your views on the timing of the first rate hike?',
#   'label': 0},
#  {'text': 'G-7 statement seemed to indicate that policymakers would use tools',
#   'label': 0},
#  {'text': 'Here is the full text of the statement issued by the Federal Reserve:',
#   'label': 0},
#  {'text': 'The Committee voted unanimously to elect Frederic Mishkin as associate economist from the Federal Reserve Bank of New York.',
#   'label': 2},
#  {'text': 'The outlook for economic growth is likely to be determined by the speed with which a new financial architecture emerges.',
#   'label': 0},
#  {'text': 'The drag on demand and profits from rising energy costs, as well as eroding consumer confidence, reports of substantial shortfalls in sales and earnings.',
#   'label': 0},
#  {'text': "Chair Powell: It's not about the strength of the labor market.",
#   'label': 2},
#  {'text': "I am the director of the Federal Reserve Board's Division of Consumer and Community Affairs",
#   'label': 0},
#  {'text': 'Chairman Powell: It is premature to think about pausing rate hikes',
#   'label': 2},
#  {'text': 'Deposit insurance, discount window, and daylight overdrafts have played a critical role.',
#   'label': 0},
#  {'text': 'Here is the full text of the remarks made by the Board of Governors on Basel II.',
#   'label': 0},
#  {'text': 'Public sector must engage to ensure payments infrastructure is safe.',
#   'label': 0},
#  {'text': 'A large increase in nonfarm payroll employment led to a small decline in the civilian unemployment rate.',
#   'label': 1},
#  {'text': 'The Federal Open Market Committee decided to keep the target for the federal funds rate at 6 percent.',
#   'label': 1},
#  {'text': 'authorizing the purchase and sale of foreign currencies on the open market.',
#   'label': 1},
#  {'text': 'The Federal Open Market Committee decided today to keep its target for the federal funds rate at 1-1/4 percent.',
#   'label': 1},
#  {'text': 'Information received since the Federal Open Market Committee met in September suggests that economic activity has continued to pick up.',
#   'label': 1},
#  {'text': "What can we do to make sure that doesn't happen again?",
#   'label': 2},
#  {'text': 'The Federal Open Market Committee held the federal funds rate at 1 percent.',
#   'label': 1},
#  {'text': "Here is the full text of Fed chair's remarks at press conference.",
#   'label': 2},
#  {'text': 'The Committee voted unanimously to approve the domestic policy directive.',
#   'label': 1},
#  {'text': 'Information received since the Federal Open Market Committee met in April indicates that the economic recovery is continuing at a moderate pace.',
#   'label': 1},
#  {'text': 'Watch the full interview with Fed chair Janet Yellen on Fox Business.',
#   'label': 0},
#  {'text': 'New measures to support recovery and employment growth',
#   'label': 1},
#  {'text': 'The Federal Reserve will keep the target for the federal funds rate at 1 percent.',
#   'label': 2},
#  {'text': 'Chair: We have had downward revisions to the level of potential output.',
#   'label': 2},
#  {'text': 'Access to credit is a major issue, but Fed policy not helping broad public.',
#   'label': 1},
#  {'text': 'Lowers target for federal funds rate by 50 basis points to 1 1/4 percent. Board of Governors also reduces discount rate to 3/4 percent',
#   'label': 1},
#  {'text': 'Chair Powell answers question about disinflation at press conference.',
#   'label': 2},
#  {'text': "MarketWatch's Robb looks at why some Republicans are hostile to Wall Street.",
#   'label': 1},
#  {'text': 'Here is the full text of Fed Listens:', 'label': 0},
#  {'text': 'Watch the full interview with Federal Reserve chair Janet Yellen.',
#   'label': 0},
#  {'text': 'Oil price drop gives Fed more room to keep rates low.', 'label': 2},
#  {'text': "Peter looks at the numbers from the outside and says it doesn't look like the Fed is meeting its goals.",
#   'label': 1},
#  {'text': 'Panel to discuss setting own 2 percent inflation target.',
#   'label': 1},
#  {'text': 'Chairman Powell: We expect a full range of data and information on all these issues',
#   'label': 0},
#  {'text': "Here is the text of Fed chair Janet Yellen's speech at the Massachusetts Institute of Technology.",
#   'label': 0},
#  {'text': 'Is there a point at which you think, publicly or privately, you should push back on the President?',
#   'label': 0},
#  {'text': 'The Board of Governors unanimously approved a 25 basis point increase in the discount rate to 2 percent.',
#   'label': 2},
#  {'text': 'Below is the statement issued by the Federal Reserve after its latest meeting:',
#   'label': 0},
#  {'text': 'Here is the full question and answer from Jon Hilsenrath.',
#   'label': 1},
#  {'text': 'The Committee decided to raise the target range for the federal funds rate to 4 to 4 percent.',
#   'label': 2},
#  {'text': 'Federal Open Market Committee votes unanimously to accept Report of Examination of the System Open Market Account.',
#   'label': 1},
#  {'text': 'System open market operations, including reinvestment into agency-guaranteed mortgage-backed securities.',
#   'label': 1},
#  {'text': "Chairman: I have confidence in the FOMC's ability to forecast the economy.",
#   'label': 1},
#  {'text': 'Here is the full text of remarks by Chair Yellen at press conference:',
#   'label': 2},
#  {'text': 'Below is the full text of G20 statement on Basel II:', 'label': 0},
#  {'text': 'The Committee decided to keep the target range for the federal funds rate at 0 to 1/4 percent.',
#   'label': 1},
#  {'text': 'Information received since the Committee met in March suggests that economic activity has continued to strengthen.',
#   'label': 1},
#  {'text': 'I was going to tell you the exact pattern of future interest rates over the next 12 months. I was going to tell you the exact pattern of future',
#   'label': 2},
#  {'text': 'Mike Derby with Dow Jones on the state of the repo market.',
#   'label': 0},
#  {'text': 'The Committee held the target for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': "Here is the full text of Powell's remarks:", 'label': 0},
#  {'text': 'The Committee judges that policy accommodation can be maintained for a considerable period.',
#   'label': 1},
#  {'text': "Here is the full text of Chairman Bernanke's press conference.",
#   'label': 1},
#  {'text': 'Watch the full interview with Fed chair Powell on Fox Business Network.',
#   'label': 2},
#  {'text': 'Q&A follows: Chair Powell on bill purchases, repos', 'label': 0},
#  {'text': 'Wages grew 3.1 percent year-over-year in May.', 'label': 0},
#  {'text': "I think there's number of things in train that will make the mortgage markets more open:",
#   'label': 1},
#  {'text': 'The Committee decided to keep the target range for the federal funds rate at 0 to 1/4 percent.',
#   'label': 1},
#  {'text': 'Information received since the Federal Open Market Committee met in June suggests that economic activity expanded at a modest pace.',
#   'label': 1},
#  {'text': 'Here is the full question and answer from Michael Derby.',
#   'label': 2},
#  {'text': 'The following statement is released after the Federal Reserve meeting in Washington.',
#   'label': 1},
#  {'text': 'Community Reinvestment Act now covers all insured depository institutions.',
#   'label': 2},
#  {'text': "I don't see commercial real estate as analogous to this.",
#   'label': 2},
#  {'text': 'Is it something the Fed could consider if the crisis got worse?',
#   'label': 1},
#  {'text': 'Chairman: We take a balanced approach to policy.', 'label': 1},
#  {'text': 'Larry Summers: U.S. is in middle of its own lost decade',
#   'label': 1},
#  {'text': 'Decision to keep target range for funds rate at 11/2 to 1 percent.',
#   'label': 1},
#  {'text': 'Decision to initiate right purchases of inflation-indexedTreasury securities.',
#   'label': 1},
#  {'text': 'Final demand had expanded at a solid pace in the second quarter.',
#   'label': 2},
#  {'text': 'Q&A with Powell on inflation, economic outlook', 'label': 2},
#  {'text': 'Pandemic is different from trickle-down economics: Da Costa.',
#   'label': 1},
#  {'text': 'Resolution to establish temporary reciprocal currency swap arrangements with the Reserve Bank of New Zealand.',
#   'label': 0},
#  {'text': 'Below is the joint statement by central banks on their actions:',
#   'label': 0},
#  {'text': 'Below is the text of the statement issued after the FOMC meeting.',
#   'label': 2},
#  {'text': 'I have a couple of questions about the virus.', 'label': 0},
#  {'text': 'Information received since the Federal Open Market Committee met in March indicates that the economy has continued to contract.',
#   'label': 1},
#  {'text': "Chair Powell: We don't talk about this kind of recession.",
#   'label': 2},
#  {'text': "Here is the text of Bank of England governor's remarks on proposed new accord:",
#   'label': 0},
#  {'text': 'Central banks should define price stability in terms of a desired range of inflation outcomes.',
#   'label': 0},
#  {'text': "Here is the full text of Bank of England governor's remarks:",
#   'label': 0},
#  {'text': 'Panel discussion on the importance of financial sector for monetary policy.',
#   'label': 0},
#  {'text': 'Information received suggested that the economy expanded at a moderate pace over the third quarter and into the current quarter.',
#   'label': 2},
#  {'text': 'Here is the text of my remarks at the St. Louis Fed conference.',
#   'label': 0},
#  {'text': 'Pace of financial technology has had profound impact on economy.',
#   'label': 2},
#  {'text': 'Staff briefings discussed threshold-based forward guidance, balance sheet policies.',
#   'label': 2},
#  {'text': 'At the February meeting, the Committee raised the limit on outright holdings of U.S. government securities to $12 billion.',
#   'label': 1},
#  {'text': 'Federal deposit insurance has been a potent force for stability.',
#   'label': 0},
#  {'text': "I would say it's not something we're considering right now and not something we expect to consider in the near term.",
#   'label': 2},
#  {'text': 'The Committee decided to extend for one year the reciprocal currency arrangements with the Bank of Canada and the Banco de Mexico.',
#   'label': 2},
#  {'text': 'Here is the full text of the interview with Fed chair Powell.',
#   'label': 2},
#  {'text': 'Financial markets have been front and center in recent FOMC discussions.',
#   'label': 0},
#  {'text': 'The Committee decided to add the euro to the list of foreigncurrencies it is authorized to conduct open market operations.',
#   'label': 1},
#  {'text': 'Here is the full statement from Fed chair:', 'label': 2},
#  {'text': 'Core PCE index comes in stronger than expected.', 'label': 2},
#  {'text': 'The Board of Governors unanimously approved a 50-basis-point increase in the federal funds rate to 1 percent.',
#   'label': 2},
#  {'text': 'The Federal Reserve will keep the target for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': "Chair Powell: We're a long way from that", 'label': 0},
#  {'text': 'The Federal Open Market Committee at its meeting today decided to lower its target for the federal funds rate.',
#   'label': 0},
#  {'text': "Here is a question from a CNBC viewer about Powell's inflation forecast.",
#   'label': 2},
#  {'text': 'Is there anything the Fed can do or should do if there are large budget cuts?',
#   'label': 1},
#  {'text': 'Is the second round of securities purchases effective?',
#   'label': 1},
#  {'text': 'Here is the full text of the remarks by Fed chair Powell.',
#   'label': 2},
#  {'text': 'Here is the full text of the testimony by Janet Yellen:',
#   'label': 0},
#  {'text': "Here is the full text of Powell's press conference:", 'label': 2},
#  {'text': 'The Federal Reserve decided to keep the target for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': 'Open market operations are designed to promote trading in federal funds.',
#   'label': 1},
#  {'text': 'What would have been downsides to cutting rates now?', 'label': 0},
#  {'text': 'The following statement is released by the Federal Reserve:',
#   'label': 1},
#  {'text': "Here is the full text of Ben Bernanke's press conference on Thursday.",
#   'label': 1},
#  {'text': 'Ukraine, China shocks are likely to add to headline inflation.',
#   'label': 2},
#  {'text': 'Here is the full question and answer from Fed Chairman Powell.',
#   'label': 2},
#  {'text': 'Chairman, Jon Hilsenrath from the Wall Street Journal.',
#   'label': 1},
#  {'text': 'I think the Committee would be focused on short-term rates as our key tool of policy.',
#   'label': 2},
#  {'text': 'The G-10 task forces on financial consolidation produced a Summary Report.',
#   'label': 0},
#  {'text': 'I want to raise with you some of the issues I have considered as I think about Y2K.',
#   'label': 2},
#  {'text': 'Panel discussed potential changes to Committee’s Statement on Longer-Run Goals and Monetary Policy Strategy. System Open Market Account manager reviewed U.S. financial',
#   'label': 1},
#  {'text': 'Hard data are critical in the work of community organizations.',
#   'label': 0},
#  {'text': 'Q&A: What changed between last week and today?', 'label': 0},
#  {'text': "Here is the full text of Fed chair Yellen's speech on Tuesday.",
#   'label': 2},
#  {'text': 'Information received since the Federal Open Market Committee met in June suggests that economic activity is leveling out.',
#   'label': 1},
#  {'text': 'Q&A with Greg Ip of Economist on inflation, more QE.', 'label': 1},
#  {'text': "Here is the full text of Chairman Powell's press conference:",
#   'label': 2},
#  {'text': "Here is the full text of Chairman Powell's press conference:",
#   'label': 0},
#  {'text': 'Pace of policy accommodation to be removed at pace likely to be measured.',
#   'label': 2},
#  {'text': "The Committee decided to extend for one year the System's reciprocal currency arrangements with the Bank of Canada and the Bank of Mexico.",
#   'label': 1},
#  {'text': 'Views are necessarily general because the FDIC recommendations were purposefully quite broad.',
#   'label': 0},
#  {'text': 'At this meeting, the Committee decided to keep the target for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': 'The Committee held the target range for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': 'Pace of asset purchases to be reduced to $10 billion per month.',
#   'label': 1},
#  {'text': 'Industrial organization plays important role in regulatory design.',
#   'label': 0},
#  {'text': 'Manager of the System Open Market Account presents update on potential for establishing an overnight reverse repurchase agreement.',
#   'label': 1},
#  {'text': 'To promote a stronger pace of economic recovery and to help ensure that inflation, over time, is at levels consistent with its mandate.',
#   'label': 1},
#  {'text': 'Systemically important nonbank financial companies not historically subject to consolidated prudential supervision.',
#   'label': 0},
#  {'text': 'On the recommendation of the Manager of the System Open Market Account, the Committee amended paragraph 2 of the Authorization for Domestic Open Market Operations.',
#   'label': 1},
#  {'text': 'Payment of Interest on Demand Deposits and Interest on balances held by Reserve Banks.',
#   'label': 0},
#  {'text': 'The Board of Governors of the Federal Reserve has decided to reduce the discount rate to 5 percent.',
#   'label': 1},
#  {'text': "Cuts made so far don't seem to have significant short-term consequences.",
#   'label': 1},
#  {'text': 'Economic activity was substantial in the quarter just ended. Consumer spending and business investment in durable equipment remained strong',
#   'label': 2},
#  {'text': 'Peter Barnes questions Ben Bernanke on the fiscal cliff.',
#   'label': 1},
#  {'text': 'Manager noted that U.S. equity markets had posted strong gains.',
#   'label': 1},
#  {'text': 'Chair responds to questions from reporters at press conference.',
#   'label': 2},
#  {'text': 'I will focus on an aspect of the crisis that remains something of a puzzle.',
#   'label': 2},
#  {'text': 'Fed cuts 2013 and 2014 growth forecasts.', 'label': 0},
#  {'text': 'Decision to keep the target range for the federal funds rate at 0 to 14 percent.',
#   'label': 1},
#  {'text': 'Microprudential approach to regulation was not dominant before crisis.',
#   'label': 0},
#  {'text': 'Pace of asset purchases to be reduced to $15 billion per month.',
#   'label': 1},
#  {'text': 'I will say that the forecast we have is satisfactory in one dimension.',
#   'label': 1},
#  {'text': 'Significant progress has been made over the past several years toward restoring the banking system',
#   'label': 0},
#  {'text': 'Peter Praet, Mr. Chairman, with a question about forward guidance.',
#   'label': 1},
#  {'text': 'The Committee decided to keep the target range for the federal funds rate at 0 to 1/4 percent.',
#   'label': 1},
#  {'text': 'Federal Reserve Bank of New York President:. Before turning to the latest information on credit market conditions, however, I think it important to highlight the',
#   'label': 0},
#  {'text': 'Fed chair Powell to hold press conference after rate cut.',
#   'label': 0},
#  {'text': "Says Fed wouldn't comment on whether there is now a recession.",
#   'label': 2},
#  {'text': 'I will focus on the mortgage securitization process, how it has been affected, and how it may evolve.',
#   'label': 0},
#  {'text': 'Chair Powell on labor market, wages in remarks at Fed conference.',
#   'label': 0},
#  {'text': 'Final Dodd-Frank Act rules in place, international reforms under way.',
#   'label': 0},
#  {'text': 'The committee decided to decrease slightly the degree of pressure on bank reserve positions.',
#   'label': 1},
#  {'text': "Here is the full text of Powell's remarks:", 'label': 0},
#  {'text': 'New York Fed has been in the news a lot lately.', 'label': 2},
#  {'text': 'Senator Bennett has asked us all to address the issue.',
#   'label': 2},
#  {'text': 'Staff presentation on tools that could be used to provide additional policy accommodation.',
#   'label': 1},
#  {'text': 'Dealer agreements for repurchase of securities obligations may be determined by competitive bidding.',
#   'label': 1},
#  {'text': "I think it's very hard to say with precise certainty the way this is going to unfold.",
#   'label': 2},
#  {'text': "Fed chair: I don't comment on fiscal policy.", 'label': 2},
#  {'text': 'Here is the full text of the questions and answers asked by Fed officials.',
#   'label': 2},
#  {'text': 'Authorization adopted, effective February 1, 2000.', 'label': 2},
#  {'text': 'Policy-oriented research will highlight U.S. housing and mortgage markets.',
#   'label': 0},
#  {'text': 'Staff briefing on potential for full-allotment overnight reverse repurchase agreement.',
#   'label': 1},
#  {'text': 'H.R. 1701 would require cost disclosures for rent-to-own transactions.',
#   'label': 0},
#  {'text': 'Has the Fed changed its stance on inflation over time?',
#   'label': 0},
#  {'text': 'Pace of asset purchases to be reduced to $25 billion per month.',
#   'label': 1},
#  {'text': 'I want to talk a little bit about the core issues in deciding whether or not that additional capital should look like.',
#   'label': 1},
#  {'text': 'Questions at Powell press conference about the impact of Brexit on the economy.',
#   'label': 2},
#  {'text': "Here is the full text of Chairman Powell's testimony before the Senate Banking Committee.",
#   'label': 2},
#  {'text': 'Reform of Glass-Steagall Act may be revived early in new Congress.',
#   'label': 0},
#  {'text': 'Federal Reserve chair Janet Yellen gives remarks at conference in Frankfurt.',
#   'label': 0},
#  {'text': 'Q&A with Chairman Bernanke on inflation expectations.', 'label': 1},
#  {'text': 'Peter Barnes of FOX Business questions Ben Bernanke.', 'label': 1},
#  {'text': 'Chair Powell spoke at the Economic Club of Washington on Thursday.',
#   'label': 2},
#  {'text': 'Directs the Federal Reserve Bank of New York to carry out the most recent domestic policy directive.',
#   'label': 1},
#  {'text': 'Community Affairs report is published by the Federal Reserve System.',
#   'label': 0},
#  {'text': 'The Committee decided to keep the target for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': 'Governor: Reducing regulatory burden is important for MDIs',
#   'label': 0},
#  {'text': 'The Committee held the target range for the federal funds rate at 0 to 0.25%.',
# ...
#  {'text': 'Q&A with Powell follows his press conference on Wednesday.',
#   'label': 2},
#  {'text': "Here is what Powell said after the Fed's latest policy decision:",
#   'label': 2},
#  {'text': 'Pace of increases in target range for funds rate to be consistent with sustained expansion of economic activity.',
#   'label': 1},
#  {'text': 'The United States and some other industrial countries experienced large capital inflows for more than a decade.',
#   'label': 0},
#  {'text': 'Chairman: We have discussed a range of things that we can do.',
#   'label': 1},
#  {'text': 'Low- and moderate-income households need to save more.',
#   'label': 0},
#  {'text': 'Information received since the Federal Open Market Committee met in April suggests that the pace of economic contraction is slowing.',
#   'label': 1},
#  {'text': 'What do you make of the idea that the Fed has no more ammunition?',
#   'label': 1},
#  {'text': "I will review recent events, discuss the Federal Reserve's responses, and conclude with some comments.",
#   'label': 0},
#  {'text': 'The Committee judges that policy accommodation can be maintained for a considerable period.',
#   'label': 1},
#  {'text': 'Information received since the Federal Open Market Committee met in March indicates that the labor market has continued to strengthen.',
#   'label': 2},
#  {'text': "All participants supported the statement affirming the Federal Reserve's core values.",
#   'label': 1},
#  {'text': 'The Committee decided to keep the target for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': 'I will pay tribute to the 100 years of dedicated industrial production indexes for the U.S.',
#   'label': 0},
#  {'text': 'This paper looks at recent U.S. productivity gains, their likely causes, and their implications.',
#   'label': 0},
#  {'text': 'The Federal Open Market Committee decided to decrease slightly the degree of pressure on reserves.',
#   'label': 0},
#  {'text': 'Here is the full text of remarks by Fed chair Powell at a press conference in Washington.',
#   'label': 2},
#  {'text': 'Reform must enable community banks to maintain critical role',
#   'label': 2},
#  {'text': 'Is it possible that Fed policies are providing monetary tinder for inflation?',
#   'label': 1},
#  {'text': 'Policymakers decided to keep the target range for the federal funds rate at 1 to 2 percent.',
#   'label': 2},
#  {'text': 'Here is the full text of Chairman Powell’s statement:', 'label': 2},
#  {'text': 'Study finds that FOMC statements have a significant impact on market interest rates.',
#   'label': 0},
#  {'text': 'Nice to have you here again. Powell: Labor market is moving back into balance',
#   'label': 2},
#  {'text': 'I would like to take on the role of Janus. I would like to look back on the experiences of the past 10 years, what the FSB has',
#   'label': 0},
#  {'text': 'Chairman: This is not a Main Street policy.', 'label': 1},
#  {'text': "No market strains emerged with the closing of nearly all of the Federal Reserve's remaining special liquidity facilities.",
#   'label': 1},
#  {'text': '‘Ideas, not vested interests, are dangerous for good or evil.’ J.M. Keynes, 1936',
#   'label': 0},
#  {'text': 'Weekly take on events in the world economy and their fallout.',
#   'label': 1},
#  {'text': 'The following statement is released after the Federal Open Market Committee meeting:',
#   'label': 1},
#  {'text': 'Is there still a large output gap, and is core inflation going to return to mandate-consistent levels?',
#   'label': 1},
#  {'text': 'Slow pace of wage increases reflects slack in labor market.',
#   'label': 2},
#  {'text': 'The Federal Reserve has taken decisive actions to address the crisis.',
#   'label': 0},
#  {'text': 'Record-long U.S. economic expansion is close to maximum employment',
#   'label': 0},
#  {'text': 'Lower bound rose again, this represents 17 different views.',
#   'label': 0},
#  {'text': 'Is there a specific number for the level of inflation?',
#   'label': 2},
#  {'text': 'Fed says short-term rates will stay near current levels through mid-2013.',
#   'label': 1},
#  {'text': 'I will discuss the necessity for institutions to improve linkage between strategy and risk management.',
#   'label': 0},
#  {'text': 'Pace of asset purchases to be reduced to $5 billion per month.',
#   'label': 2},
#  {'text': 'System Open Market Account manager first discussed developments in financial markets. Open Market Desk surveys suggested that market participants anticipated a sharp near-term decline in economic activity',
#   'label': 1},
#  {'text': "Here is the full text of Chairman Powell's press conference.",
#   'label': 2},
#  {'text': 'Here is the text of remarks by Federal Reserve chair Janet Yellen.',
#   'label': 0},
#  {'text': 'Deflation concerns were raised at the Fed meeting.', 'label': 2},
#  {'text': 'President Obama has said that he wants to cut the deficit, not raise taxes.',
#   'label': 1},
#  {'text': 'Pace of purchases to be brought to an end in early March.',
#   'label': 2},
#  {'text': 'Price stability should be an objective of monetary policy.',
#   'label': 0},
#  {'text': "Here is the full text of Bank of England governor Mervyn King's speech:",
#   'label': 1},
#  {'text': 'Pace of asset purchases to be reduced to $20 billion per month.',
#   'label': 1},
#  {'text': "Here is the full text of Powell's remarks at theInflation Report:",
#   'label': 0},
#  {'text': "Here is the full text of Powell's testimony:", 'label': 2},
#  {'text': 'The Committee decided to maintain the target range for the federal funds rate at 5 to 5-1/4 percent.',
#   'label': 2},
#  {'text': "Here is the full text of President Obama's remarks at the White House press conference.",
#   'label': 2},
#  {'text': 'Officers elected to serve until the election of their successors at the first regularly scheduled meeting.',
#   'label': 1},
#  {'text': 'Private nonfarm payrolls grew in September for first time since January. Labor markets appear to be leveling out, industrial output strengthens',
#   'label': 1},
#  {'text': 'Federal Reserve Bank of San Francisco conference on Tuesday.',
#   'label': 0},
#  {'text': 'To buy or sell Eligible Securities: on a same-day or deferred delivery basis, to purchase or sale under Section 14(b) of the Federal',
#   'label': 0},
#  {'text': 'To support a stronger economic recovery and to help ensure that inflation, over time, is at levels consistent with the dual mandate, the Committee decided today to',
#   'label': 1},
#  {'text': 'At this meeting, the Committee decided to merge the currentMinutes of Actions with the Record of Policy Actions.',
#   'label': 1},
#  {'text': 'Black unemployment rate is roughly double the rate for white workers. Chair Powell: Two sides of mandate not in tension',
#   'label': 2},
#  {'text': 'The Committee decided to keep the target for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': 'Federal Reserve chair Janet Yellen gives remarks at conference in Frankfurt.',
#   'label': 0},
#  {'text': 'Real-time payment and settlement service to be developed by Federal Reserve.',
#   'label': 0},
#  {'text': 'Economic globalization has been a powerful force for growth.',
#   'label': 0},
#  {'text': 'Purchases and sales of Eligible Securities may be made on a same-day or deferred delivery basis.',
#   'label': 2},
#  {'text': 'SEP reflects economic readings, not just rate increase.',
#   'label': 2},
#  {'text': 'To: (a) To buy or sell U.S. Government securities, including securities of the Federal Financing Bank, and securities that are direct obligations',
#   'label': 1},
#  {'text': 'Chair responds to question about market expectations.', 'label': 2},
#  {'text': 'The committee decided to increase slightly the degree of pressure on reserve positions.',
#   'label': 2},
#  {'text': 'Pace of economic recovery is likely to be moderate for a time.',
#   'label': 1},
#  {'text': 'I would say that we are deeply committed to carrying out our mission, and also that our independence from political control is an important institutional feature',
#   'label': 0},
#  {'text': 'I will lay out how I think about the interplay between financial markets and monetary policy.',
#   'label': 0},
#  {'text': "I can't tell you today what the actual size will be.", 'label': 2},
#  {'text': 'Greater price flexibility has reduced incentive for central banks to boost output.',
#   'label': 0},
#  {'text': 'I will try to put these developments in the context of the recent course of our economy.',
#   'label': 0},
#  {'text': "I think it's fair to say that medium-term inflation expectations have not really moved very much.",
#   'label': 1},
#  {'text': 'The following is the text of my remarks at the ICBA conference:',
#   'label': 0},
#  {'text': 'Questions on inflation, unemployment and more from reporters.',
#   'label': 2},
#  {'text': 'I grew up in the small town of Dillon. I got my wish when I left to go to Harvard',
#   'label': 0},
#  {'text': 'The Committee noted that economic activity increased at a slow pace in the third quarter.',
#   'label': 1},
#  {'text': 'Has the level of dissent been surprising or abnormal?', 'label': 2},
#  {'text': 'Here is the full text of the statement issued by the FOMC:',
#   'label': 0},
#  {'text': 'I would say it is progress but without any weakening in labor market conditions.',
#   'label': 2},
#  {'text': 'Here is the full text of remarks by Fed chair Janet Yellen:',
#   'label': 1},
#  {'text': 'Here is the full text of the questions asked of Ben Bernanke.',
#   'label': 1},
#  {'text': 'Broader availability of mortgage credit contributed to rise in homeownership rate',
#   'label': 0},
#  {'text': 'I would like to review briefly the vulnerabilities in the financial system that contributed to the crisis.',
#   'label': 0},
#  {'text': "Here is the full text of Chairman Powell's remarks:", 'label': 2},
#  {'text': 'Two questions in the statement of exit principles stand out.',
#   'label': 2},
#  {'text': 'Questions for Powell on risks from commercial real estate market.',
#   'label': 2},
#  {'text': "Here is the text of Ben Bernanke's remarks at the St. Louis Fed conference.",
#   'label': 0},
#  {'text': 'I think the right thing to do is to wait and see more.',
#   'label': 0},
#  {'text': 'I would agree with argument that a significant part of decline over and above the downward trend in participation rate is reflecting cyclical factors.',
#   'label': 0},
#  {'text': 'Federal Reserve chair Ben Bernanke addresses the Cosmos Club.',
#   'label': 2},
#  {'text': 'U.S. agencies plan to issue preliminary proposals for implementation next month.',
#   'label': 0},
#  {'text': "Chairman: I'm not going to get involved in political rhetoric.",
#   'label': 1},
#  {'text': 'Federal Reserve chair Janet Yellen addresses coalition.',
#   'label': 2},
#  {'text': "Chairman: No, that's a very good question.", 'label': 1},
#  {'text': 'I will review recent developments in the U.S. current account and provide an update.',
#   'label': 0},
#  {'text': 'What impact would the virus have on the U.S. economy?', 'label': 0},
#  {'text': 'I believe a highly accommodative monetary policy will be needed for some time.',
#   'label': 0},
#  {'text': "Here is the full text of Chairman Bernanke's remarks:", 'label': 1},
#  {'text': 'The Federal Reserve decided to keep the target for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': "Here are some highlights from Tuesday's press conference.",
#   'label': 2},
#  {'text': 'Here is the full text of the remarks by Fed chair Janet Yellen.',
#   'label': 0},
#  {'text': 'Chairman, can you give us a number for how much this is going to cost?',
#   'label': 0},
#  {'text': 'Evan Ryser questions Powell on inflation, QT.', 'label': 2},
#  {'text': "Here is the full text of Chair Powell's press conference:",
#   'label': 2},
#  {'text': "Chair Powell says it's too early to assess the full impact of policy",
#   'label': 2},
#  {'text': 'At this meeting, the Committee decided to keep the target for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': 'Committee approved the following:', 'label': 1},
#  {'text': 'Here is the full text of the remarks by Fed chair Powell:',
#   'label': 2},
#  {'text': "I wouldn't say it was bad, but it was worse than expected",
#   'label': 2},
#  {'text': 'Staff briefings provided an assessment of the risk that the federal funds rate could be constrained by the effective lower bound.',
#   'label': 1},
#  {'text': 'Chair Powell: We believe we can get to that state at the current pace',
#   'label': 0},
#  {'text': 'First Lady cuts ribbon at new Finance Park in Fairfax County',
#   'label': 0},
#  {'text': 'U.S. Secretary of State John Kerry says he expects July decision to be a "live" meeting.',
#   'label': 2},
#  {'text': 'Here is the text of remarks by San Francisco Fed chair:',
#   'label': 2},
#  {'text': 'Ip says central banks can provide financial accommodation.',
#   'label': 1},
#  {'text': "Fed chair says policy is in a good place, but there's still work to do",
#   'label': 2},
#  {'text': 'I think it is appropriate to make an adjustment to a somewhat more accommodative policy.',
#   'label': 0},
#  {'text': 'Do you think such actions to ease policy will put more pressure on the Fed?',
#   'label': 0},
#  {'text': 'The Committee sees downside risks to growth and to prices as significant.',
#   'label': 0},
#  {'text': 'Is it possible to forecast more accurately with less data?',
#   'label': 2},
#  {'text': 'System Open Market Account manager spoke on financial markets, short-term funding markets.',
#   'label': 1},
#  {'text': "U.S. banks have been arguing they can't afford to do that.",
#   'label': 1},
#  {'text': 'Reforms in recent years have led to a more efficient financial system.',
#   'label': 0},
#  {'text': 'Federal Reserve Bank of Atlanta conference program', 'label': 2},
#  {'text': "Here is the full text of Chair Powell's remarks at the press conference.",
#   'label': 2},
#  {'text': 'Here are highlights of remarks by Fed chair and other G-7 officials',
#   'label': 0},
#  {'text': 'The Committee decided to keep the target range for the federal funds rate at 5-1/4 to 5 percent.',
#   'label': 1},
#  {'text': 'Information received since the Federal Open Market Committee met in January suggests a return to moderate economic growth.',
#   'label': 1},
#  {'text': "I wouldn't say it's the decisive part of the picture.", 'label': 2},
#  {'text': 'The Federal Open Market Committee decided to keep its target for the federal funds rate unchanged at 1 percent.',
#   'label': 1},
#  {'text': 'Expansion of balance sheet not intended to alter stance of policy.',
#   'label': 2},
#  {'text': 'The Committee held the target range for the federal funds rate at 0 to 0.25%.',
#   'label': 1},
#  {'text': 'Staff presented approaches for controlling short-term interest rates.',
#   'label': 1},
#  {'text': 'Policymakers decided to leave the target range for the federal funds rate at between zero and 0.25%.',
#   'label': 1},
#  {'text': 'Survey respondents projected midpoint of target range to peak at 3.13 percent.',
#   'label': 2},
#  {'text': 'Staff briefings discussed potential upward pressures on federal funds rate.',
#   'label': 1},
#  {'text': 'U.S. central bankers are involved in talks with European leaders, Fed chair says.',
#   'label': 1},
#  {'text': 'Fifty years ago, we could see on the horizon vast new means of communication.',
#   'label': 0},
#  {'text': 'Risk-management models pose challenges for risk managers.',
#   'label': 2},
#  {'text': 'Is debate about lower-for-longer essentially over?', 'label': 2},
#  {'text': 'It is a testimony to American perseverance that the conference is going forward in cyberspace.',
#   'label': 0},
#  {'text': 'Q&A follows: What is the best guess on when rates will go up?',
#   'label': 1},
#  {'text': 'The Federal Reserve releases the following statement after its Open Market Committee meeting.',
#   'label': 2},
#  {'text': 'The FOMC directed that the stance of monetary policy be tilted toward a firming.',
#   'label': 2},
#  {'text': 'Here is the full text of the speech by Federal Reserve chair Janet Yellen:',
#   'label': 0},
#  {'text': "Here is the text of President Obama's address to the Florida Black Business Investment Board.",
#   'label': 0},
#  ...]

# %% [markdown]
# fine tuning del primer modelo

# %%
import torch
import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from tqdm import tqdm
from torch.optim import AdamW
from torch.utils.data import DataLoader
import os

# Define labels
labels = ['negative', 'neutral', 'positive']

# Load pre-trained model and tokenizer
tokenizer = AutoTokenizer.from_pretrained('cardiffnlp/twitter-roberta-base-sentiment')
model_roberta = AutoModelForSequenceClassification.from_pretrained('cardiffnlp/twitter-roberta-base-sentiment')

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_roberta.to(device)

# Function to preprocess data (replace with your data loading logic)
def preprocess_data(data):
  # Tokenize text and convert labels to tensors
  input_ids = tokenizer(data["text"], return_tensors="pt", padding=True, truncation=True).input_ids.to(device)
  attention_mask = tokenizer(data["text"], return_tensors="pt", padding=True, truncation=True).attention_mask.to(device)
  labels = torch.tensor(data["label"]).to(device)
  return input_ids, attention_mask, labels

from transformers import AutoModelForSequenceClassification
import torch
from tqdm.auto import tqdm
import numpy as pd
from torch.utils.data import DataLoader

# Define training and validation functions
def train(model, optimizer, train_data, epoch, writer):
  model.train()
  losses = []
  accuracies = []
  for data in tqdm(train_data):
    input_ids, attention_mask, labels = preprocess_data(data)
    optimizer.zero_grad()
    outputs = model(input_ids=input_ids, attention_mask=attention_mask)
    logits = outputs.logits
    loss = torch.nn.functional.cross_entropy(logits, labels)
    loss.backward()
    optimizer.step()
    losses.append(loss.item())
    # Calculate accuracy
    predictions = torch.argmax(logits, dim=1)
    correct = (predictions == labels).sum().item()
    accuracy = correct / len(labels)
    accuracies.append(accuracy)
  avg_loss = np.mean(losses)
  avg_accuracy = np.mean(accuracies)
  writer.add_scalar("Train/Loss", avg_loss, epoch)
  writer.add_scalar("Train/Accuracy", avg_accuracy, epoch)
  print(f"Epoch {epoch+1} - Train Loss: {avg_loss:.4f}, Train Accuracy: {avg_accuracy:.4f}")
  return avg_loss, avg_accuracy

def validate(model, val_data, writer, epoch):
  model.eval()
  losses = []
  accuracies = []
  with torch.no_grad():
    for data in val_data:
      input_ids, attention_mask, labels = preprocess_data(data)
      outputs = model(input_ids=input_ids, attention_mask=attention_mask)
      logits = outputs.logits
      loss = torch.nn.functional.cross_entropy(logits, labels)
      losses.append(loss.item())
      # Calculate accuracy
      predictions = torch.argmax(logits, dim=1)
      correct = (predictions == labels).sum().item()
      accuracy = correct / len(labels)
      accuracies.append(accuracy)
  avg_loss = np.mean(losses)
  avg_accuracy = np.mean(accuracies)
  writer.add_scalar("Val/Loss", avg_loss, epoch)
  writer.add_scalar("Val/Accuracy", avg_accuracy, epoch)
  print(f"Validation Loss: {avg_loss:.4f}, Validation Accuracy: {avg_accuracy:.4f}")
  return avg_loss, avg_accuracy

# Hyperparameter tuning (experiment with different learning rates and batch sizes)
learning_rates = [1e-5, 2e-5, 5e-5]
batch_sizes = [16, 32, 64]

# Load your training and validation data (replace with your data)
train_data = train_data  # Load your training data here
val_data = val_data  # Load your validation data here

# Train-validation loop with hyperparameter search
best_val_accuracy = 0
for lr in learning_rates:
  for batch_size in batch_sizes:
    # Define optimizer and data loaders
    optimizer = AdamW(model_roberta.parameters(), lr=lr)
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_data, batch_size=batch_size)

    # Early stopping variables
    epochs = 3  # Set the number of epochs
    patience = 2  # Number of epochs to wait for improvement
    no_improvement = 0

    # TensorBoard for visualization (optional)
    from torch.utils.tensorboard import SummaryWriter
    writer = SummaryWriter(f"runs/roberta_sentiment_{lr}_{batch_size}")

    for epoch in range(epochs):
      train_loss, train_acc = train(model_roberta, optimizer, train_loader, epoch, writer)
      val_loss, val_acc = validate(model_roberta, val_loader, writer, epoch)

      # Define a variable for the desired save directory
      save_directory = "C:\\Users\\luisl\\OneDrive\\Escritorio\\TFM_IA3\\tfm_ia3_nodata\\models"  # Ensure double backslashes for Windows paths

      # Early stopping with model saving
      if val_acc > best_val_accuracy:
          best_val_accuracy = val_acc
          no_improvement = 0
          # Save the best model in the specified directory
          torch.save(model_roberta.state_dict(), os.path.join(save_directory, f"best_model_{lr}_{batch_size}_V2.pt"))
          print(f"Saving best model with validation accuracy: {val_acc:.4f}")
      else:
          no_improvement += 1
          if no_improvement >= patience:
              print(f"Early stopping triggered after {no_improvement} epochs without improvement")
              break  # Exit the inner loop for this hyperparameter combination
# Out:
#   0%|          | 0/68 [00:00<?, ?it/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# C:\Users\luisl\AppData\Local\Temp\ipykernel_10744\738944181.py:25: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(data["label"]).to(device)
# Epoch 1 - Train Loss: 1.1799, Train Accuracy: 0.3864
# Validation Loss: 1.0410, Validation Accuracy: 0.4816
# Saving best model with validation accuracy: 0.4816
#   0%|          | 0/68 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.9852, Train Accuracy: 0.5398
# Validation Loss: 0.9926, Validation Accuracy: 0.4816
#   0%|          | 0/68 [00:00<?, ?it/s]
# Epoch 3 - Train Loss: 0.8457, Train Accuracy: 0.6173
# Validation Loss: 0.8993, Validation Accuracy: 0.5772
# Saving best model with validation accuracy: 0.5772
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.6981, Train Accuracy: 0.7203
# Validation Loss: 0.9313, Validation Accuracy: 0.6181
# Saving best model with validation accuracy: 0.6181
#   0%|          | 0/34 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 110
#     107 writer = SummaryWriter(f"runs/roberta_sentiment_{lr}_{batch_size}")
#     109 for epoch in range(epochs):
# --> 110   train_loss, train_acc = train(model_roberta, optimizer, train_loader, epoch, writer)
#     111   val_loss, val_acc = validate(model_roberta, val_loader, writer, epoch)
#     113   # Define a variable for the desired save directory
#
# Cell In[25], line 45, in train(model, optimizer, train_data, epoch, writer)
#      43 logits = outputs.logits
#      44 loss = torch.nn.functional.cross_entropy(logits, labels)
# ---> 45 loss.backward()
#      46 optimizer.step()
#      47 losses.append(loss.item())
#
# File c:\Users\luisl\anaconda3\envs\tfm_modelado\lib\site-packages\torch\_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File c:\Users\luisl\anaconda3\envs\tfm_modelado\lib\site-packages\torch\autograd\__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %% [markdown]
# carga del primer modelo reentrenado

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Define labels
labels = ['negative', 'neutral', 'positive']

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained('cardiffnlp/twitter-roberta-base-sentiment')

# Define the path to the saved model (assuming the model is saved in a folder)
model_path = "C:/Users/luisl/OneDrive/Escritorio/TFM_IA3/tfm_ia3_nodata/models/best_model_1e-05_32.pt"  # Replace with your actual path

# Function to preprocess text
def preprocess_text(text, tokenizer):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    input_ids = inputs.input_ids.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
    attention_mask = inputs.attention_mask.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
    return input_ids, attention_mask

# Load the model
model_finbert = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")
model_finbert.load_state_dict(torch.load(model_path))
model_finbert.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))  # Move to GPU if available

with torch.no_grad():
    model_finbert.eval()

    # Example usage
    text = "The stock market is booming!"
    input_ids, attention_mask = preprocess_text(text, tokenizer)

    # Get predictions
    outputs = model_finbert(input_ids=input_ids, attention_mask=attention_mask)
    logits = outputs.logits
    predicted_label = torch.argmax(logits, dim=1).item()

    # Get the predicted sentiment
    predicted_sentiment = labels[predicted_label]

    print(f"Predicted sentiment for '{text}': {predicted_sentiment}")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Predicted sentiment for 'The stock market is booming!': positive

# %% [markdown]
# twitter-roberta-base-sentiment Model¶

# %%
import torch
import numpy as np
import scipy.special
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from tqdm import tqdm

# Cargar el tokenizer y el modelo
tokenizer = AutoTokenizer.from_pretrained('cardiffnlp/twitter-roberta-base-sentiment')
model_roberta = AutoModelForSequenceClassification.from_pretrained('cardiffnlp/twitter-roberta-base-sentiment')

# Mover el modelo a la GPU si está disponible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_roberta.to(device)

tokenizer_kwargs = {"padding": True, "truncation": True, "max_length": 512}
labels = ['negative', 'neutral', 'positive']

# Asumiendo que X_submuestra es tu lista de textos a analizar
preds_roberta = []
preds_proba_roberta = []

for x in tqdm(X_submuestra, desc="Procesando predicciones"):
    with torch.no_grad():
        # Tokenizar y mover el texto completo a la GPU
        input_sequence = tokenizer(x, return_tensors="pt", **tokenizer_kwargs).to(device)
        # Obtener las logits del modelo
        logits = model_roberta(**input_sequence).logits
        # Aplicar softmax en la GPU
        scores = torch.softmax(logits, dim=1).cpu().numpy().squeeze()
    
    sentimiento_general = labels[np.argmax(scores)]
    probabilidad_general = np.max(scores)
    
    preds_roberta.append(sentimiento_general)
    preds_proba_roberta.append(probabilidad_general)
# Out:
# Procesando predicciones: 100%|██████████| 1359/1359 [00:33<00:00, 40.12it/s]

# %%
submuestra_df['predicted_roberta'] = preds_roberta; submuestra_df
# Out:
#                  type       date  \
# 51          statement 2003-08-12
# 1100           speech 2000-02-23
# 1312        testimony 2001-06-20
# 514   presconf_script 2012-01-25
# 1074           speech 1999-06-01
# ...               ...        ...
# 1095           speech 2000-01-13
# 1130           speech 2001-04-26
# 1294           speech 2020-02-06
# 860   presconf_script 2022-06-15
# 1126           speech 2001-03-09
#
#                                                   title  \
# 51                                       FOMC Statement
# 1100  How does a surplus affect the formulation and ...
# 1312               Condition of the U.S. banking system
# 514                    FOMC Press Conference Transcript
# 1074         Dilemmas facing United States policymakers
# ...                                                 ...
# 1095                                Inflation targeting
# 1130              Understanding financial consolidation
# 1294  The Economic Outlook, Monetary Policy, and the...
# 860                    FOMC Press Conference Transcript
# 1126              Understanding financial consolidation
#
#                                            speaker  word_count  decision  \
# 51                                  Alan Greenspan        1057         0
# 1100                    Governor Laurence H. Meyer        3782      <NA>
# 1312                                Alan Greenspan        1141      <NA>
# 514                                   Ben Bernanke         237         0
# 1074                    Vice Chair Alice M. Rivlin        2167      <NA>
# ...                                            ...         ...       ...
# 1095                   Governor Edward M. Gramlich        4265      <NA>
# 1130          Vice Chairman Roger W. Ferguson, Jr.        3177      <NA>
# 1294  Vice Chair for Supervision Randal K. Quarles        3076      <NA>
# 860                    MICHELLE SMITH. Nancy. NANC         253         1
# 1126          Vice Chairman Roger W. Ferguson, Jr.        2910      <NA>
#
#       rate next_meeting next_decision  next_rate  \
# 51     1.0   2003-09-15             0       1.00
# 1100   NaN   2000-03-21             1       6.00
# 1312   NaN   2001-06-27            -1       3.75
# 514    0.0   2012-03-13             0       0.00
# 1074   NaN   1999-06-30             1       5.00
# ...    ...          ...           ...        ...
# 1095   NaN   2000-02-02             1       5.75
# 1130   NaN   2001-05-15            -1       4.00
# 1294   NaN   2020-03-03            -1       1.00
# 860    1.5   2022-07-27             1       2.25
# 1126   NaN   2001-03-20            -1       5.00
#
#                                                    text  \
# 51    For immediate releaseThe Federal Open Market C...
# 1100  This is a conference on fiscal policy, specifi...
# 1312  Mr. Chairman and members of the Committee, I a...
# 514   Steve, there's certainly been some encouraging...
# 1074  So much has happened on the world economics sc...
# ...                                                 ...
# 1095  At one time or another, opinions on how centra...
# 1130  In recognition of the importance of this marke...
# 1294  I would like to thank the organizers for the o...
# 860   MARSHALL-GENZER. Hi, Chair Powell. Nancy Marsh...
# 1126  Consolidation of all types of business activit...
#
#                                                 summary predicted_roberta
# 51    The Committee judges that policy accommodation...           neutral
# 1100  I will give remarks today at the National Asso...           neutral
# 1312  Asset quality is deteriorating, supervisors ne...          negative
# 514   Chairman Bernanke: We are prepared to take fur...           neutral
# 1074  Russian default, Brazil devaluation, Europe's ...           neutral
# ...                                                 ...               ...
# 1095  New Zealand was the first country to adopt a f...           neutral
# 1130  Mergers and acquisitions were a major feature ...           neutral
# 1294  Here is the text of the speech by Fed chair Ja...           neutral
# 860   Chair Powell says the Fed is focused on gettin...           neutral
# 1126  I would like to discuss the G-10 study of fina...           neutral
#
# [1359 rows x 13 columns]

# %% [markdown]
# yiyanghkust/finbert-tone Model

# %%
import torch
import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from tqdm import tqdm
from torch.optim import AdamW
from torch.utils.data import DataLoader

# Define labels
labels = ['negative', 'neutral', 'positive']

# Load pre-trained model and tokenizer
tokenizer = AutoTokenizer.from_pretrained('yiyanghkust/finbert-tone')
model_roberta = AutoModelForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone')

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_roberta.to(device)

# Function to preprocess data (replace with your data loading logic)
def preprocess_data(data):
  # Tokenize text and convert labels to tensors
  input_ids = tokenizer(data["text"], return_tensors="pt", padding=True, truncation=True).input_ids.to(device)
  attention_mask = tokenizer(data["text"], return_tensors="pt", padding=True, truncation=True).attention_mask.to(device)
  labels = torch.tensor(data["label"]).to(device)
  return input_ids, attention_mask, labels

from transformers import AutoModelForSequenceClassification
import torch
from tqdm.auto import tqdm
import numpy as pd
from torch.utils.data import DataLoader

# Define training and validation functions
def train(model, optimizer, train_data, epoch, writer):
  model.train()
  losses = []
  accuracies = []
  for data in tqdm(train_data):
    input_ids, attention_mask, labels = preprocess_data(data)
    optimizer.zero_grad()
    outputs = model(input_ids=input_ids, attention_mask=attention_mask)
    logits = outputs.logits
    loss = torch.nn.functional.cross_entropy(logits, labels)
    loss.backward()
    optimizer.step()
    losses.append(loss.item())
    # Calculate accuracy
    predictions = torch.argmax(logits, dim=1)
    correct = (predictions == labels).sum().item()
    accuracy = correct / len(labels)
    accuracies.append(accuracy)
  avg_loss = np.mean(losses)
  avg_accuracy = np.mean(accuracies)
  writer.add_scalar("Train/Loss", avg_loss, epoch)
  writer.add_scalar("Train/Accuracy", avg_accuracy, epoch)
  print(f"Epoch {epoch+1} - Train Loss: {avg_loss:.4f}, Train Accuracy: {avg_accuracy:.4f}")
  return avg_loss, avg_accuracy

def validate(model, val_data, writer, epoch):
  model.eval()
  losses = []
  accuracies = []
  with torch.no_grad():
    for data in val_data:
      input_ids, attention_mask, labels = preprocess_data(data)
      outputs = model(input_ids=input_ids, attention_mask=attention_mask)
      logits = outputs.logits
      loss = torch.nn.functional.cross_entropy(logits, labels)
      losses.append(loss.item())
      # Calculate accuracy
      predictions = torch.argmax(logits, dim=1)
      correct = (predictions == labels).sum().item()
      accuracy = correct / len(labels)
      accuracies.append(accuracy)
  avg_loss = np.mean(losses)
  avg_accuracy = np.mean(accuracies)
  writer.add_scalar("Val/Loss", avg_loss, epoch)
  writer.add_scalar("Val/Accuracy", avg_accuracy, epoch)
  print(f"Validation Loss: {avg_loss:.4f}, Validation Accuracy: {avg_accuracy:.4f}")
  return avg_loss, avg_accuracy

# Hyperparameter tuning (experiment with different learning rates and batch sizes)
learning_rates = [1e-5, 2e-5, 5e-5]
batch_sizes = [16, 32, 64]

# Load your training and validation data (replace with your data)
train_data = train_data  # Load your training data here
val_data = val_data  # Load your validation data here

# Train-validation loop with hyperparameter search
best_val_accuracy = 0
for lr in learning_rates:
  for batch_size in batch_sizes:
    # Define optimizer and data loaders
    optimizer = AdamW(model_roberta.parameters(), lr=lr)
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_data, batch_size=batch_size)

    # Early stopping variables
    epochs = 3  # Set the number of epochs
    patience = 2  # Number of epochs to wait for improvement
    no_improvement = 0

    # TensorBoard for visualization (optional)
    from torch.utils.tensorboard import SummaryWriter
    writer = SummaryWriter(f"runs/roberta_sentiment_{lr}_{batch_size}")

    for epoch in range(epochs):
      train_loss, train_acc = train(model_roberta, optimizer, train_loader, epoch, writer)
      val_loss, val_acc = validate(model_roberta, val_loader, writer, epoch)

      # Define a variable for the desired save directory
      save_directory = "C:\\Users\\luisl\\OneDrive\\Escritorio\\TFM_IA3\\tfm_ia3_nodata\\models"  # Ensure double backslashes for Windows paths

      # Early stopping with model saving
      if val_acc > best_val_accuracy:
          best_val_accuracy = val_acc
          no_improvement = 0
          # Save the best model in the specified directory
          torch.save(model_roberta.state_dict(), os.path.join(save_directory, f"best_model_2_{lr}_{batch_size}_V2.pt"))
          print(f"Saving best model with validation accuracy: {val_acc:.4f}")
      else:
          no_improvement += 1
          if no_improvement >= patience:
              print(f"Early stopping triggered after {no_improvement} epochs without improvement")
              break  # Exit the inner loop for this hyperparameter combination
# Out:
#   0%|          | 0/68 [00:00<?, ?it/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# C:\Users\luisl\AppData\Local\Temp\ipykernel_14560\975409393.py:24: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(data["label"]).to(device)
# Epoch 1 - Train Loss: 1.9009, Train Accuracy: 0.4186
# Validation Loss: 1.0172, Validation Accuracy: 0.4779
# Saving best model with validation accuracy: 0.4779
#   0%|          | 0/68 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.9468, Train Accuracy: 0.5539
# Validation Loss: 0.9266, Validation Accuracy: 0.5993
# Saving best model with validation accuracy: 0.5993
#   0%|          | 0/68 [00:00<?, ?it/s]
# Epoch 3 - Train Loss: 0.8232, Train Accuracy: 0.6395
# Validation Loss: 0.9431, Validation Accuracy: 0.6066
# Saving best model with validation accuracy: 0.6066
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.7489, Train Accuracy: 0.6843
# Validation Loss: 0.9183, Validation Accuracy: 0.6250
# Saving best model with validation accuracy: 0.6250
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.5549, Train Accuracy: 0.7654
# Validation Loss: 0.9697, Validation Accuracy: 0.6042
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 3 - Train Loss: 0.4673, Train Accuracy: 0.8233
# Validation Loss: 0.9608, Validation Accuracy: 0.6354
# Saving best model with validation accuracy: 0.6354
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.3964, Train Accuracy: 0.8573
# Validation Loss: 1.0096, Validation Accuracy: 0.6687
# Saving best model with validation accuracy: 0.6687
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.3253, Train Accuracy: 0.8841
# Validation Loss: 1.0337, Validation Accuracy: 0.6656
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 3 - Train Loss: 0.2940, Train Accuracy: 0.8952
# Validation Loss: 1.1357, Validation Accuracy: 0.6438
# Early stopping triggered after 2 epochs without improvement
#   0%|          | 0/68 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.4163, Train Accuracy: 0.8435
# Validation Loss: 1.3861, Validation Accuracy: 0.5956
#   0%|          | 0/68 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.2831, Train Accuracy: 0.9025
# Validation Loss: 1.4531, Validation Accuracy: 0.6103
# Early stopping triggered after 2 epochs without improvement
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.2421, Train Accuracy: 0.9172
# Validation Loss: 1.4188, Validation Accuracy: 0.6424
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.1792, Train Accuracy: 0.9475
# Validation Loss: 1.4523, Validation Accuracy: 0.6076
# Early stopping triggered after 2 epochs without improvement
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.1808, Train Accuracy: 0.9328
# Validation Loss: 1.4654, Validation Accuracy: 0.6719
# Saving best model with validation accuracy: 0.6719
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.1266, Train Accuracy: 0.9512
# Validation Loss: 1.5308, Validation Accuracy: 0.6656
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 3 - Train Loss: 0.1216, Train Accuracy: 0.9595
# Validation Loss: 1.5721, Validation Accuracy: 0.6656
# Early stopping triggered after 2 epochs without improvement
#   0%|          | 0/68 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.3770, Train Accuracy: 0.8804
# Validation Loss: 2.0530, Validation Accuracy: 0.5735
#   0%|          | 0/68 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.3115, Train Accuracy: 0.8952
# Validation Loss: 1.5404, Validation Accuracy: 0.6103
# Early stopping triggered after 2 epochs without improvement
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.3098, Train Accuracy: 0.8998
# Validation Loss: 1.9115, Validation Accuracy: 0.6528
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.2126, Train Accuracy: 0.9291
# Validation Loss: 1.8048, Validation Accuracy: 0.6528
# Early stopping triggered after 2 epochs without improvement
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.1721, Train Accuracy: 0.9430
# Validation Loss: 1.8680, Validation Accuracy: 0.6438
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.1470, Train Accuracy: 0.9485
# Validation Loss: 1.6203, Validation Accuracy: 0.6687
# Early stopping triggered after 2 epochs without improvement

# %% [markdown]
# carga de segundo modelo reentrenado

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Define labels
labels = ['negative', 'neutral', 'positive']

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained('yiyanghkust/finbert-tone')

# Define the path to the saved model (assuming the model is saved in a folder)
model_path = "C:/Users/luisl/OneDrive/Escritorio/TFM_IA3/tfm_ia3_nodata/models/best_model_2_2e-05_64.pt"  # Replace with your actual path

# Function to preprocess text
def preprocess_text(text, tokenizer):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    input_ids = inputs.input_ids.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
    attention_mask = inputs.attention_mask.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
    return input_ids, attention_mask

# Load the model
model_finbert = AutoModelForSequenceClassification.from_pretrained("yiyanghkust/finbert-tone")
model_finbert.load_state_dict(torch.load(model_path))
model_finbert.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))  # Move to GPU if available

with torch.no_grad():
    model_finbert.eval()

    # Example usage
    text = "The stock market is doing great!"
    input_ids, attention_mask = preprocess_text(text, tokenizer)

    # Get predictions
    outputs = model_finbert(input_ids=input_ids, attention_mask=attention_mask)
    logits = outputs.logits
    predicted_label = torch.argmax(logits, dim=1).item()

    # Get the predicted sentiment
    predicted_sentiment = labels[predicted_label]

    print(f"Predicted sentiment for '{text}': {predicted_sentiment}")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Predicted sentiment for 'The stock market is doing great!': positive

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification, pipeline
import pandas as pd
from tqdm.auto import tqdm

# Inicialización del modelo y tokenizer
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')
finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone', num_labels=3)

# Mover el modelo a la GPU si está disponible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
finbert.to(device)

nlp = pipeline("sentiment-analysis", model=finbert, tokenizer=tokenizer, device=0 if torch.cuda.is_available() else -1)

# Asumiendo que submuestra_df es tu DataFrame y tiene una columna 'text'
predicted_finbert_tone = []

for text in tqdm(submuestra_df['summary'], desc="Analizando sentimientos"):
    with torch.no_grad():
        # Tokenizar y mover el texto completo a la GPU
        result = nlp(text)[0]
    
    sentimiento_final = result['label'].lower()
    predicted_finbert_tone.append(sentimiento_final)

# Añadir los resultados al DataFrame
submuestra_df['predicted_finbertTone'] = predicted_finbert_tone
# Out:
# Analizando sentimientos:   0%|          | 0/1359 [00:00<?, ?it/s]

# %% [markdown]
# ProsusAI/finbert Model

# %%
import torch
import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from tqdm import tqdm
from torch.optim import AdamW
from torch.utils.data import DataLoader

# Define labels
labels = ['negative', 'neutral', 'positive']

# Load pre-trained model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model_roberta = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_roberta.to(device)

# Function to preprocess data (replace with your data loading logic)
def preprocess_data(data):
  # Tokenize text and convert labels to tensors
  input_ids = tokenizer(data["text"], return_tensors="pt", padding=True, truncation=True).input_ids.to(device)
  attention_mask = tokenizer(data["text"], return_tensors="pt", padding=True, truncation=True).attention_mask.to(device)
  labels = torch.tensor(data["label"]).to(device)
  return input_ids, attention_mask, labels

from transformers import AutoModelForSequenceClassification
import torch
from tqdm.auto import tqdm
import numpy as pd
from torch.utils.data import DataLoader

# Define training and validation functions
def train(model, optimizer, train_data, epoch, writer):
  model.train()
  losses = []
  accuracies = []
  for data in tqdm(train_data):
    input_ids, attention_mask, labels = preprocess_data(data)
    optimizer.zero_grad()
    outputs = model(input_ids=input_ids, attention_mask=attention_mask)
    logits = outputs.logits
    loss = torch.nn.functional.cross_entropy(logits, labels)
    loss.backward()
    optimizer.step()
    losses.append(loss.item())
    # Calculate accuracy
    predictions = torch.argmax(logits, dim=1)
    correct = (predictions == labels).sum().item()
    accuracy = correct / len(labels)
    accuracies.append(accuracy)
  avg_loss = np.mean(losses)
  avg_accuracy = np.mean(accuracies)
  writer.add_scalar("Train/Loss", avg_loss, epoch)
  writer.add_scalar("Train/Accuracy", avg_accuracy, epoch)
  print(f"Epoch {epoch+1} - Train Loss: {avg_loss:.4f}, Train Accuracy: {avg_accuracy:.4f}")
  return avg_loss, avg_accuracy

def validate(model, val_data, writer, epoch):
  model.eval()
  losses = []
  accuracies = []
  with torch.no_grad():
    for data in val_data:
      input_ids, attention_mask, labels = preprocess_data(data)
      outputs = model(input_ids=input_ids, attention_mask=attention_mask)
      logits = outputs.logits
      loss = torch.nn.functional.cross_entropy(logits, labels)
      losses.append(loss.item())
      # Calculate accuracy
      predictions = torch.argmax(logits, dim=1)
      correct = (predictions == labels).sum().item()
      accuracy = correct / len(labels)
      accuracies.append(accuracy)
  avg_loss = np.mean(losses)
  avg_accuracy = np.mean(accuracies)
  writer.add_scalar("Val/Loss", avg_loss, epoch)
  writer.add_scalar("Val/Accuracy", avg_accuracy, epoch)
  print(f"Validation Loss: {avg_loss:.4f}, Validation Accuracy: {avg_accuracy:.4f}")
  return avg_loss, avg_accuracy

# Hyperparameter tuning (experiment with different learning rates and batch sizes)
learning_rates = [1e-5, 2e-5, 5e-5]
batch_sizes = [16, 32, 64]

# Load your training and validation data (replace with your data)
train_data = train_data  # Load your training data here
val_data = val_data  # Load your validation data here

# Train-validation loop with hyperparameter search
best_val_accuracy = 0
for lr in learning_rates:
  for batch_size in batch_sizes:
    # Define optimizer and data loaders
    optimizer = AdamW(model_roberta.parameters(), lr=lr)
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_data, batch_size=batch_size)

    # Early stopping variables
    epochs = 3  # Set the number of epochs
    patience = 2  # Number of epochs to wait for improvement
    no_improvement = 0

    # TensorBoard for visualization (optional)
    from torch.utils.tensorboard import SummaryWriter
    writer = SummaryWriter(f"runs/roberta_sentiment_{lr}_{batch_size}")

    for epoch in range(epochs):
      train_loss, train_acc = train(model_roberta, optimizer, train_loader, epoch, writer)
      val_loss, val_acc = validate(model_roberta, val_loader, writer, epoch)

      # Define a variable for the desired save directory
      save_directory = "C:\\Users\\luisl\\OneDrive\\Escritorio\\TFM_IA3\\tfm_ia3_nodata\\models"  # Ensure double backslashes for Windows paths

      # Early stopping with model saving
      if val_acc > best_val_accuracy:
          best_val_accuracy = val_acc
          no_improvement = 0
          # Save the best model in the specified directory
          torch.save(model_roberta.state_dict(), os.path.join(save_directory, f"best_model_3_{lr}_{batch_size}_V2.pt"))
          print(f"Saving best model with validation accuracy: {val_acc:.4f}")
      else:
          no_improvement += 1
          if no_improvement >= patience:
              print(f"Early stopping triggered after {no_improvement} epochs without improvement")
              break  # Exit the inner loop for this hyperparameter combination
# Out:
#   0%|          | 0/68 [00:00<?, ?it/s]
# C:\Users\luisl\AppData\Local\Temp\ipykernel_14560\2617414119.py:24: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(data["label"]).to(device)
# Epoch 1 - Train Loss: 1.2285, Train Accuracy: 0.4148
# Validation Loss: 1.0423, Validation Accuracy: 0.4890
# Saving best model with validation accuracy: 0.4890
#   0%|          | 0/68 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.9437, Train Accuracy: 0.5521
# Validation Loss: 0.9941, Validation Accuracy: 0.5515
# Saving best model with validation accuracy: 0.5515
#   0%|          | 0/68 [00:00<?, ?it/s]
# Epoch 3 - Train Loss: 0.7756, Train Accuracy: 0.6534
# Validation Loss: 0.9230, Validation Accuracy: 0.6287
# Saving best model with validation accuracy: 0.6287
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.6019, Train Accuracy: 0.7599
# Validation Loss: 0.9453, Validation Accuracy: 0.6424
# Saving best model with validation accuracy: 0.6424
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.4889, Train Accuracy: 0.8132
# Validation Loss: 1.0257, Validation Accuracy: 0.6389
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 3 - Train Loss: 0.4111, Train Accuracy: 0.8519
# Validation Loss: 1.0511, Validation Accuracy: 0.6076
# Early stopping triggered after 2 epochs without improvement
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.3378, Train Accuracy: 0.8914
# Validation Loss: 1.0954, Validation Accuracy: 0.6000
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.2955, Train Accuracy: 0.9024
# Validation Loss: 1.1322, Validation Accuracy: 0.6125
# Early stopping triggered after 2 epochs without improvement
#   0%|          | 0/68 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.3598, Train Accuracy: 0.8721
# Validation Loss: 1.3259, Validation Accuracy: 0.5735
#   0%|          | 0/68 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.2909, Train Accuracy: 0.8988
# Validation Loss: 1.2885, Validation Accuracy: 0.6066
# Early stopping triggered after 2 epochs without improvement
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.2669, Train Accuracy: 0.8988
# Validation Loss: 1.2181, Validation Accuracy: 0.6111
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.1885, Train Accuracy: 0.9292
# Validation Loss: 1.3149, Validation Accuracy: 0.6250
# Early stopping triggered after 2 epochs without improvement
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.1644, Train Accuracy: 0.9402
# Validation Loss: 1.3017, Validation Accuracy: 0.6594
# Saving best model with validation accuracy: 0.6594
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.1414, Train Accuracy: 0.9458
# Validation Loss: 1.3861, Validation Accuracy: 0.6125
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 3 - Train Loss: 0.1190, Train Accuracy: 0.9521
# Validation Loss: 1.4893, Validation Accuracy: 0.6344
# Early stopping triggered after 2 epochs without improvement
#   0%|          | 0/68 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.3057, Train Accuracy: 0.8860
# Validation Loss: 1.4529, Validation Accuracy: 0.6029
#   0%|          | 0/68 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.2555, Train Accuracy: 0.9099
# Validation Loss: 1.5857, Validation Accuracy: 0.6103
# Early stopping triggered after 2 epochs without improvement
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.2223, Train Accuracy: 0.9099
# Validation Loss: 1.6202, Validation Accuracy: 0.6007
#   0%|          | 0/34 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.1723, Train Accuracy: 0.9355
# Validation Loss: 1.6212, Validation Accuracy: 0.6042
# Early stopping triggered after 2 epochs without improvement
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 1 - Train Loss: 0.1557, Train Accuracy: 0.9384
# Validation Loss: 1.6767, Validation Accuracy: 0.6031
#   0%|          | 0/17 [00:00<?, ?it/s]
# Epoch 2 - Train Loss: 0.1175, Train Accuracy: 0.9549
# Validation Loss: 1.7897, Validation Accuracy: 0.5875
# Early stopping triggered after 2 epochs without improvement

# %% [markdown]
# cargar tercer modelo reentrenado

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Define labels
labels = ['negative', 'neutral', 'positive']

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained('ProsusAI/finbert')

# Define the path to the saved model (assuming the model is saved in a folder)
model_path = "C:/Users/luisl/OneDrive/Escritorio/TFM_IA3/tfm_ia3_nodata/models/best_model_3_2e-05_64.pt"  # Replace with your actual path

# Function to preprocess text
def preprocess_text(text, tokenizer):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    input_ids = inputs.input_ids.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
    attention_mask = inputs.attention_mask.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
    return input_ids, attention_mask

# Load the model
model_finbert = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")
model_finbert.load_state_dict(torch.load(model_path))
model_finbert.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))  # Move to GPU if available

with torch.no_grad():
    model_finbert.eval()

    # Example usage
    text = "The stock market is doing great!"
    input_ids, attention_mask = preprocess_text(text, tokenizer)

    # Get predictions
    outputs = model_finbert(input_ids=input_ids, attention_mask=attention_mask)
    logits = outputs.logits
    predicted_label = torch.argmax(logits, dim=1).item()

    # Get the predicted sentiment
    predicted_sentiment = labels[predicted_label]

    print(f"Predicted sentiment for '{text}': {predicted_sentiment}")
# Out:
# Predicted sentiment for 'The stock market is doing great!': negative

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from tqdm.auto import tqdm
import numpy as np

# Inicialización del tokenizer y el modelo
tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model_finbert = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")

# Mover el modelo a la GPU si está disponible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_finbert.to(device)

preds = []
preds_proba = []
tokenizer_kwargs = {"padding": True, "truncation": True, "max_length": 512}

for x in tqdm(X_submuestra, desc="Procesando predicciones FinBERT"):
    with torch.no_grad():
        # Tokenizar y mover el texto completo a la GPU
        input_sequence = tokenizer(x, return_tensors="pt", **tokenizer_kwargs).to(device)
        logits = model_finbert(**input_sequence).logits
        scores = torch.softmax(logits, dim=1).cpu().numpy().squeeze()
        scores_dict = {
            label: score
            for label, score in zip(model_finbert.config.id2label.values(), scores)
        }
        sentimiento = max(scores_dict, key=scores_dict.get)
        probabilidad = max(scores_dict.values())
    
    preds.append(sentimiento)
    preds_proba.append(probabilidad)
# Out:
# Procesando predicciones FinBERT:   0%|          | 0/1359 [00:00<?, ?it/s]

# %%
submuestra_df['predicted_finbert'] =preds

# %% [markdown]
# hacer la columna sentiment en el dataset de entrenamiento teniendo en cuenta las agregaciones de key y cambiar de 1 a positive etc

# %%
y = submuestra_df['next_decision'].to_list()
y = [ 'neutral' if value == 0 else 'positive' if value == 1 else 'negative' for value in y ]

# %%
submuestra_df.tail()
# Out:
#                  type       date  \
# 1095           speech 2000-01-13
# 1130           speech 2001-04-26
# 1294           speech 2020-02-06
# 860   presconf_script 2022-06-15
# 1126           speech 2001-03-09
#
#                                                   title  \
# 1095                                Inflation targeting
# 1130              Understanding financial consolidation
# 1294  The Economic Outlook, Monetary Policy, and the...
# 860                    FOMC Press Conference Transcript
# 1126              Understanding financial consolidation
#
#                                            speaker  word_count  decision  \
# 1095                   Governor Edward M. Gramlich        4265      <NA>
# 1130          Vice Chairman Roger W. Ferguson, Jr.        3177      <NA>
# 1294  Vice Chair for Supervision Randal K. Quarles        3076      <NA>
# 860                    MICHELLE SMITH. Nancy. NANC         253         1
# 1126          Vice Chairman Roger W. Ferguson, Jr.        2910      <NA>
#
#       rate next_meeting next_decision  next_rate  \
# 1095   NaN   2000-02-02             1       5.75
# 1130   NaN   2001-05-15            -1       4.00
# 1294   NaN   2020-03-03            -1       1.00
# 860    1.5   2022-07-27             1       2.25
# 1126   NaN   2001-03-20            -1       5.00
#
#                                                    text  \
# 1095  At one time or another, opinions on how centra...
# 1130  In recognition of the importance of this marke...
# 1294  I would like to thank the organizers for the o...
# 860   MARSHALL-GENZER. Hi, Chair Powell. Nancy Marsh...
# 1126  Consolidation of all types of business activit...
#
#                                                 summary predicted_roberta  \
# 1095  New Zealand was the first country to adopt a f...           neutral
# 1130  Mergers and acquisitions were a major feature ...           neutral
# 1294  Here is the text of the speech by Fed chair Ja...           neutral
# 860   Chair Powell says the Fed is focused on gettin...           neutral
# 1126  I would like to discuss the G-10 study of fina...           neutral
#
#      predicted_finbertTone predicted_finbert
# 1095               neutral           neutral
# 1130               neutral           neutral
# 1294               neutral           neutral
# 860                neutral          positive
# 1126               neutral           neutral

# %%
submuestra_df['text'][0]
# Out:
# "Chairman Alan Greenspan announced today that the Federal Open Market Committee decided to increase slightly the degree of pressure on reserve positions. The action is expected to be associated with a small increase in short-term money market interest rates. The decision was taken to move toward a less accommodative stance in monetary policy in order to sustain and enhance the economic expansion. Chairman Greenspan decided to announce this action immediately so as to avoid any misunderstanding of the Committee's purposes, given the fact that this is the first firming of reserve market conditions by the Committee since early 1989."

# %% [markdown]
# ## Model evaluation

# %%
def evaluate_model_accuracy(model_name, y_pred):
    accuracy = accuracy_score(y, y_pred)
    print(f'Model: {model_name} - Accuracy-Score: {accuracy:.4f}')

# %%
evaluate_model_accuracy('ProsusAI/finbert', preds)
evaluate_model_accuracy('cardiffnlp/twitter-roberta-base-sentiment', preds_roberta)
evaluate_model_accuracy('yiyanghkust/finbert-tone', submuestra_df.predicted_finbertTone)
# Out:
# Model: ProsusAI/finbert - Accuracy-Score: 0.3194
# Model: cardiffnlp/twitter-roberta-base-sentiment - Accuracy-Score: 0.3297
# Model: yiyanghkust/finbert-tone - Accuracy-Score: 0.3466

# %%
print(classification_report(y,preds))
print(classification_report(y,preds_roberta))
print(classification_report(y,submuestra_df.predicted_finbertTone))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.37      0.14      0.20       453
#      neutral       0.31      0.70      0.43       453
#     positive       0.30      0.12      0.17       453
#
#     accuracy                           0.32      1359
#    macro avg       0.33      0.32      0.27      1359
# weighted avg       0.33      0.32      0.27      1359
#
#               precision    recall  f1-score   support
#
#     negative       0.46      0.07      0.13       453
#      neutral       0.33      0.84      0.48       453
#     positive       0.25      0.08      0.12       453
#
#     accuracy                           0.33      1359
#    macro avg       0.35      0.33      0.24      1359
# weighted avg       0.35      0.33      0.24      1359
#
#               precision    recall  f1-score   support
#
#     negative       0.39      0.14      0.21       453
#      neutral       0.34      0.81      0.48       453
#     positive       0.33      0.08      0.13       453
#
#     accuracy                           0.35      1359
#    macro avg       0.35      0.35      0.27      1359
# weighted avg       0.35      0.35      0.27      1359

# %%
cm = confusion_matrix(y, preds_roberta)

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()

# %%
cm = confusion_matrix(y, preds)

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()

# %%
cm = confusion_matrix(y, submuestra_df.predicted_finbertTone)

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.title('Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()
